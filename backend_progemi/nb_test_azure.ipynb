# %%
import re

import io

import json

import tiktoken

from itertools import cycle

from math import sqrt


from pathlib import Path

from typing import Optional, List, Tuple, Sequence, Any

from pydantic import BaseModel

from azure.core.credentials import AzureKeyCredential

from azure.ai.documentintelligence import DocumentIntelligenceClient

from azure.ai.documentintelligence.models import (
    DocumentAnalysisFeature,
    AnalyzeResult,
    DocumentContentFormat,
    DocumentParagraph,
    DocumentTable,
    DocumentStyle,
    DocumentWord,
    DocumentPage,
)

from app.proposal_object.path import ProposalObjectPaths

from langchain.schema import BaseMessage, HumanMessage, SystemMessage

from app.cost.cost import CostTracker

from app.proposal_object.schemas import Devis

from app.proposal_object.proposal_object_analyzer import ProposalObjectHandler

from config.logger_config import logger

from config.config import env_param

# %%
cost_tracker = CostTracker()

# %%
AZURE_DI_ENDPOINT = "https://cleed-di.cognitiveservices.azure.com/"

AZURE_DI_KEY = "ae3ff9603ad64f81bf052eeee5a1ffae"

# %%
### Hard ###
FILE_NAME = "Devis DE2502-580 - LABOURDETTE - "

FILE_NAME = "733656-00 SAS LE CARBET LOT B MEN PVC ALU BI 7016 FT"

FILE_NAME = "SC332-0i24072310090"

FILE_NAME = (
    "DEVIS LOIRE MENUISERIES SERVICES (L_M_S_)_GUERIN - TESSIER - charnieres invisbles"
)


### Medium ###
# FILE_NAME = "Lot Electricité - JUILLARD - Devis_n°OF9206"

# FILE_NAME = "Devis - CHAINE CHAINE DES ARTISANS COTE SUD - DEVIS LARTIZIEN   1"

# FILE_NAME = "Devis_'OF9189'"

# FILE_NAME = "Devis DE2412-461 - GOURDON - "


### Easy ###
# FILE_NAME = "Devis - CHAINE CHAINE DES ARTISANS COTE SUD - Vouland   Seignosse"

proposal_path = ProposalObjectPaths(file_name=FILE_NAME)

# %%
def token_counter(text: str) -> int:
    """Count the nb of token in a text"""

    encoding = tiktoken.get_encoding("cl100k_base")

    nb_token: int = len(encoding.encode(text))

    return nb_token

# %%
# Initialiser le client Document Intelligence
client = DocumentIntelligenceClient(
    endpoint=AZURE_DI_ENDPOINT, credential=AzureKeyCredential(AZURE_DI_KEY)
)

# Analyser le document (ex. "devis.pdf") avec le modèle prebuilt-layout en activant l'extraction des styles
with open(proposal_path.proposal_path, "rb") as f:
    poller = client.begin_analyze_document(
        model_id="prebuilt-layout",
        body=f,
        features=[
            DocumentAnalysisFeature.STYLE_FONT,
            DocumentAnalysisFeature.OCR_HIGH_RESOLUTION,
        ],
        output_content_format=DocumentContentFormat.MARKDOWN,
    )

analyze_result: AnalyzeResult = poller.result()

a_out = Path(proposal_path.proposal_ocr_json_path)

a_out.parent.mkdir(parents=True, exist_ok=True)

a_out.write_text(json.dumps(analyze_result.as_dict(), indent=2, ensure_ascii=False))

print(f"✅ JSON écrit dans {a_out.resolve()}")

a_out = Path(proposal_path.proposal_ocr_content_path)

a_out.parent.mkdir(parents=True, exist_ok=True)

a_out.write_text(analyze_result.content, encoding="utf-8")

print(f"✅ TEXT écrit dans {a_out.resolve()}")


# Récupération des éléments analysés
pages: Optional[List[DocumentPage]] = analyze_result.pages  # liste des pages

paragraphs: Optional[List[DocumentParagraph]] = (
    analyze_result.paragraphs
)  # blocs de texte (paragraphes) avec contenu et position

tables: Optional[List[DocumentTable]] = (
    analyze_result.tables
)  # tableaux détectés avec leurs cellules:contentReference[oaicite:3]{index=3}

styles: Optional[List[DocumentStyle]] = (
    analyze_result.styles
)  # styles de texte détectés (gras, italique, couleur, etc.):contentReference[oaicite:4]{index=4}

content: Optional[str] = (
    analyze_result.content
)  # tout le texte du document en un seul flux (ordre de lecture)
# Out:
# ✅ JSON écrit dans /Users/remillieux/Documents/Kleek/OCR/data/proposal_ocr_json/DEVIS LOIRE MENUISERIES SERVICES (L_M_S_)_GUERIN - TESSIER - charnieres invisbles.json
# ✅ TEXT écrit dans /Users/remillieux/Documents/Kleek/OCR/data/proposal_ocr_content/DEVIS LOIRE MENUISERIES SERVICES (L_M_S_)_GUERIN - TESSIER - charnieres invisbles.txt

# %% [markdown]
# # Get line

# %%
class LineStyle(BaseModel):
    # ── infos « brutes » ───────────────────────────────────────
    font_weight: Optional[str] = None  # « bold » ou « normal »
    font_style: Optional[str] = None  # « italic » ou « normal »
    font_size: Optional[float] = None
    color: Optional[str] = None
    font_family: Optional[str] = None
    background_color: Optional[str] = None  # facultatif

    # ── propriétés dérivées ───────────────────────────────────
    @property
    def is_bold(self) -> bool:
        return (self.font_weight or "").lower() == "bold"

    @property
    def is_italic(self) -> bool:
        return (self.font_style or "").lower() == "italic"


# ────────────────────────────────────────────────────────────────
class Cell(BaseModel):
    row_index: int
    column_index: int
    content: str
    offset_px: float
    offset_span: int
    span_len: int
    polygon: Sequence[float]
    word_used_for_size: Optional[str] = None  # mot utilisé pour la taille


class TableRow(BaseModel):
    """Représente une ligne de tableau avec ses cellules"""

    row_index: int

    cells: List[Cell]

    level_h: int = 5

    line_styles: List[LineStyle] = []


class Table(BaseModel):
    offset_span: int

    len_span: int

    table_rows: List[TableRow]

    # ── offset maximal (px) par colonne ─────────────────────────
    def _col_offset_max(self) -> List[float]:
        mx: List[float] = []
        for row in self.table_rows:
            for c in row.cells:
                i = c.column_index
                if i >= len(mx):
                    mx.append(c.offset_px)
                else:
                    mx[i] = max(mx[i], c.offset_px)
        return mx

    # ── largeur (indent relative + texte) par colonne ───────────
    def _col_width(self, col_offset_max: List[float]) -> List[int]:
        w: List[int] = [0] * len(col_offset_max)
        for row in self.table_rows:
            for c in row.cells:
                i = c.column_index
                if i == 0:
                    indent = int(c.offset_px * MULT)
                else:
                    indent = int(max(0, (c.offset_px - col_offset_max[i - 1])) * MULT)
                w[i] = max(w[i], indent + len(c.content))
        return w

    # ── affichage ───────────────────────────────────────────────
    def print_table(self) -> None:
        col_off = self._col_offset_max()
        col_w = self._col_width(col_off)

        for row in self.table_rows:
            parts = [" " * col_w[i] for i in range(len(col_w))]

            for c in row.cells:
                i = c.column_index
                if i == 0:
                    indent = int(c.offset_px * MULT)
                else:
                    indent = int(max(0, (c.offset_px - col_off[i - 1])) * MULT)
                cell_txt = (" " * indent + c.content).ljust(col_w[i])
                parts[i] = cell_txt

            print(SEP.join(parts).rstrip())


# 20 icônes fixes dans lesquelles on pioche
ICONS = [
    "-",
    "_",
    "#",
    "•",
    "◦",
    "▪",
    "▫",
    "►",
    "▸",
    "‣",
    "➤",
    "→",
    "⇒",
    "★",
    "☆",
    "✓",
    "✗",
    "■",
    "□",
    "◆",
]


def hex_to_rgb(hex_code: str) -> Optional[tuple[int, int, int]]:
    """'#a1b2c3' -> (161, 178, 195) ; insensible à la casse."""
    hex_code = hex_code.strip().lstrip("#")
    if len(hex_code) != 6:
        return None
    r, g, b = (int(hex_code[i : i + 2], 16) for i in (0, 2, 4))
    return r, g, b


def rgb_distance(c1: tuple[int, int, int], c2: tuple[int, int, int]) -> float:
    """Distance euclidienne dans l’espace RGB (0-255)."""
    return sqrt(sum((a - b) ** 2 for a, b in zip(c1, c2)))


def assign_icons(colors: set[str], threshold: float = 10.0) -> dict[str, str]:
    """
    Associe à chaque couleur une icône.
    Les couleurs dont la distance RGB ≤ `threshold` partagent la même icône.
    Renvoie un dict {couleur_hex -> icône}.
    """
    # Tourniquet infini sur la liste d’icônes
    icon_pool = cycle(ICONS)

    groups: list[tuple[tuple[int, int, int], str]] = []  # [(rgb_référence, icône)]
    mapping: dict[str, str] = {}

    for hex_code in colors:
        rgb = hex_to_rgb(hex_code)

        if rgb is None:
            continue
        # Cherche un groupe existant assez proche
        for ref_rgb, icon in groups:
            if rgb_distance(rgb, ref_rgb) <= threshold:
                mapping[hex_code] = icon
                break
        else:  # aucune couleur proche : on crée un nouveau groupe
            icon = next(icon_pool)
            groups.append((rgb, icon))
            mapping[hex_code] = icon

    return mapping


def _round05(x: float) -> float:  # 12.27 → 12.5   |   11.24 → 11.0
    return round(x * 2) / 2


def _decorate(text: str, *, bold: bool, italic: bool) -> str:
    if bold:
        text = f"**{text}**"
    if italic:
        text = f"__{text}__"
    return text


def _first_cell_text(
    row: TableRow,
    raw: str,
    max_level: int,
    icon_map: dict[str, str] | None = None,
) -> str:
    # -------- icône éventuelle --------
    icon = ""
    if icon_map:  # mapping fourni ?
        for st in row.line_styles:  # parcourt les styles de la ligne
            if st.background_color in icon_map:  # 1re couleur trouvée
                icon = icon_map[st.background_color] + " "
                break

    # -------- mise en valeur bold/italic ----------
    bold = any(s.is_bold for s in row.line_styles)  # plus [:1]
    italic = any(s.is_italic for s in row.line_styles)

    return icon + _decorate(raw, bold=bold, italic=italic)


def _row_style_score(row: TableRow) -> tuple[float, int]:
    fs = _round05(next((s.font_size for s in row.line_styles if s.font_size), 0.0))
    bold = any(s.is_bold for s in row.line_styles)
    italic = any(s.is_italic for s in row.line_styles)
    style_w = (2 if bold else 0) + (-1 if italic else 0)  # plus de surligneur
    return fs, style_w


def assign_h_levels(tables: list[Table]) -> None:
    """
    Attribue à chaque ligne un level_h ∈ {1..5} uniquement selon la taille
    de police (arrondie au 0 ,5 pt).
    """
    rows = [r for t in tables for r in t.table_rows]

    # on récupère la taille (0 si indéterminée) et on arrondit au ½‐point
    for r in rows:
        fs = next((s.font_size for s in r.line_styles if s.font_size), 0.0)
        r._fs_rounded = _round05(fs)  # attribut temporaire

    # tailles distinctes, ordre décroissant
    sizes_desc = sorted({r._fs_rounded for r in rows}, reverse=True)

    # on garde au plus 5 groupes
    size2level = {sz: idx + 1 for idx, sz in enumerate(sizes_desc[:5])}

    for r in rows:
        r.level_h = size2level.get(r._fs_rounded, 5)

    # nettoyage
    for r in rows:
        del r._fs_rounded


def _page_unit(page: DocumentPage) -> str:  # déjà présent plus haut
    return getattr(page, "unit", page.unit)  # 'pixel' ou 'inch'


_METRIC = "bbox"  # <--- changez ici une bonne fois pour toutes
#   (ou passez le paramètre aux fonctions)


def _poly_height_px(
    polygon: Sequence[float], unit: str, *, dpi: int = 96, method: str = _METRIC
) -> float:
    """Hauteur du polygone selon la *métrique choisie*, convertie en px."""
    ys = polygon[1::2]  # on ne garde que les Y
    if not ys:
        return 0.0

    if method == "bbox":  # hauteur complète
        h_raw = max(ys) - min(ys)

    elif method == "mini":  # écart min2 − min1
        ys_sorted = sorted(ys)
        if len(ys_sorted) < 2:
            h_raw = 0.0
        else:
            h_raw = ys_sorted[1] - ys_sorted[0]

    else:
        raise ValueError(f"méthode inconnue : {method}")

    # conversion éventuelle
    if unit == "pixel":
        return h_raw
    if unit == "inch":
        return h_raw * dpi
    raise ValueError(f"Unité inconnue : {unit!r}")


def _intersects(a: tuple[int, int], b: tuple[int, int]) -> bool:
    """Deux intervalles de caractères se chevauchent-ils ?"""
    return not (a[1] <= b[0] or a[0] >= b[1])


def estimate_row_height_px(
    row: TableRow,
    pages: List[DocumentPage],
    *,
    dpi: int = 96,
) -> float:
    """
    Estime la hauteur d'une ligne en pixels.
    """

    max_h_px = 0.0

    for cell in row.cells[:1]:
        for page in pages:
            for word in page.words:
                if _intersects(
                    (word.span.offset, word.span.offset + word.span.length),
                    (cell.offset_span, cell.offset_span + cell.span_len),
                ):
                    # Calcule la hauteur du polygone de la cellule
                    h_px = _poly_height_px(word.polygon, unit="inch", dpi=dpi)

                    max_h_px = max(max_h_px, h_px)

                    if h_px == max_h_px:
                        cell.polygon = word.polygon

                        cell.word_used_for_size = word.content

                        return max_h_px

    return max_h_px  # 0.0 si aucun mot trouvé


# ────────────────────────────────────────────────────────────────
#  Styles Azure  ➜  LineStyle
# ────────────────────────────────────────────────────────────────
def _to_line_style(s: DocumentStyle) -> LineStyle:
    return LineStyle(
        font_size=getattr(s, "font_size", None),
        font_weight=getattr(s, "font_weight", None),
        font_style=getattr(s, "font_style", None)
        or getattr(s, "font_style_name", None),
        color=getattr(s, "color", None) or getattr(s, "font_color", None),
        font_family=getattr(s, "similar_font_family", None)
        or getattr(s, "font_family", None),
        background_color=getattr(s, "backgroundColor", None)
        or getattr(s, "background_color", None),
    )


def _styles_for_row(row: TableRow, styles: list[DocumentStyle]) -> list[LineStyle]:
    ranges = [(c.offset_span, c.offset_span + c.span_len) for c in row.cells]

    def intersects(a: tuple[int, int], b: tuple[int, int]) -> bool:
        return not (a[1] <= b[0] or a[0] >= b[1])

    out: list[LineStyle] = []
    for st in styles:
        for sp in st.spans or []:
            span_rng = (sp.offset, sp.offset + sp.length)
            if any(intersects(span_rng, r) for r in ranges):
                out.append(_to_line_style(st))
                break
    return out


def first_point_x_pixels(
    polygon: Sequence[float], *, unit: str, dpi: int = 96
) -> float:
    if not polygon or len(polygon) < 2:
        raise ValueError("Polygone invalide")

    # <<< bord gauche robustement >>>
    x_raw = min(polygon[::2])

    if unit == "pixel":
        return x_raw
    if unit == "inch":
        return x_raw * dpi
    if unit == "millimeter":
        return x_raw * dpi / 25.4
    raise ValueError(f"Unité inconnue : {unit!r}")


def _span_offset(span: Any) -> int:
    """
    Renvoie l’offset d’un objet span que ce soit :
    • un DocumentSpan SDK  → .offset
    • un dict {"offset": …}
    • un dict {"span": {"offset": …}} (JSON brut d’un word)
    """
    if span is None:
        return -1
    if hasattr(span, "offset"):
        return span.offset
    if isinstance(span, dict):
        if "offset" in span:
            return span["offset"]
        if "span" in span and "offset" in span["span"]:
            return span["span"]["offset"]
    raise ValueError("Span non reconnu")


def _table_col_widths(
    table: Table, col_off: list[float], max_level: int, bg2icon: dict[str, str] | None
) -> list[int]:
    w = [0] * len(col_off)
    for row in table.table_rows:
        for c in row.cells:
            i = c.column_index
            txt = (
                _first_cell_text(row, c.content, max_level, icon_map=bg2icon)
                if i == 0
                else c.content
            )
            indent = (
                int(c.offset_px * MULT)
                if i == 0
                else int(max(0, c.offset_px - col_off[i - 1]) * MULT)
            )
            w[i] = max(w[i], indent + len(txt))
    return w


def find_word_after_span(
    pages: List[DocumentPage],
    offset_min: int,
    target: str,
) -> Optional[DocumentWord]:
    """
    Parcourt la liste `words` **dans l’ordre** et renvoie le premier « word »
    (objet SDK ou dict JSON) dont le texte == `target`, à partir du span donné.

    Paramètres
    ----------
    words : list[DocumentWord | dict]
        Tableau de mots provenant de `page.words` ou pages[i]["words"].
    start_span : DocumentSpan | dict
        Span de référence (typiquement paragraph.spans[0] ou cell.spans[0]).
    target : str | int | float
        Mot ou nombre à chercher (ex. "300", 300, "Chauffe-eau").
    ignore_case : bool
        Si True (défaut) la comparaison n’est pas sensible à la casse.

    Retour
    ------
    DocumentWord | dict | None
        L’objet correspondant ou None si non trouvé.
    """

    target = target.lower()

    for page in pages:
        if not page.words:
            continue

        words: List[DocumentWord] = page.words

        words_sorted = sorted(
            words,
            key=lambda w: _span_offset(w.span),
        )

        for w in words_sorted:
            if w.span.offset < offset_min:
                continue

            if w.content.lower() == target:
                return w

    return None


def first_token(text: str) -> str:
    """
    Renvoie le premier mot/nombre selon la règle ci-dessus.
    Si le symbole € ou $ suit immédiatement (après blancs),
    il est inclus dans la chaîne renvoyée.

    Exemples
    --------
    >>> first_token("  - E.C. et Qté. :")
    'E.C.'
    >>> first_token(" Qté. en premier")
    'Qté.'
    >>> first_token("= 135,00 € TTC")
    '135,00 €'
    >>> first_token("Total : 99.5$")
    '99.5$'
    >>> first_token("###")
    ''
    """
    # 1) trouver les « blocs » séparés par des blancs
    for m in re.finditer(r"\S+", text):
        chunk = m.group(0)
        # doit contenir au moins une lettre ou un chiffre
        if not any(ch.isalnum() for ch in chunk):
            continue

        start = m.start()
        end = m.end()

        # 2) regarde s’il y a € ou $ juste après (en sautant les blancs)
        i = end
        while i < len(text) and text[i].isspace():
            i += 1
        if i < len(text) and text[i] in "€$":
            # on inclut tout du début du mot jusqu’au symbole compris
            return text[start : i + 1]

        # sinon on renvoie juste le bloc trouvé
        return chunk

    return ""  # aucun token valable


def _para_offset(p: DocumentParagraph) -> int:
    return p.spans[0].offset if p.spans else 2**31 - 1


def _overlaps(start: int, length: int, ranges: list[tuple[int, int]]) -> bool:
    end = start + length
    return any(not (end <= lo or start >= hi) for lo, hi in ranges)


MULT = 10  # 1 espace = 0,1 px
SEP = " | "  # séparateur


def rebuilt_tables(
    tables: List[DocumentTable], pages: List[DocumentPage], styles: list[DocumentStyle]
) -> Tuple[List[Table], List[tuple[int, int]]]:
    """Return a list of half‑open character ranges covered by *tables*."""

    print("# FOUNDING TABLES SPANS\n")

    print("There are {} tables".format(len(tables)))

    tables_rebuilt: List[Table] = []

    ranges: List[tuple[int, int]] = []

    for table in tables or []:
        table_rebuilt = Table(
            table_rows=[],
            offset_span=table.spans[0].offset if table.spans else 0,
            len_span=table.spans[0].length if table.spans else 0,
        )

        for sp in table.spans:
            ranges.append((sp.offset, sp.offset + sp.length))

        if getattr(table, "spans", None):
            for span in table.spans:
                first_table_word = table.cells[0].content if table.cells else "No cells"

                print(
                    "Table spans: {} - {} [{}]".format(
                        span.offset, span.offset + span.length, first_table_word
                    ),
                )

        print(f"\t- Nombre lignes: {table.row_count}")

        print(f"\t- Nombre colonnes: {table.column_count}")

        for cell in table.cells:
            if cell.column_index == 0:
                table_row = TableRow(
                    row_index=cell.row_index,
                    cells=[],
                )

                table_rebuilt.table_rows.append(table_row)
            if cell.content:
                first_cell_word_text: str = first_token(cell.content)

                first_cell_word_object: Optional[DocumentWord] = find_word_after_span(
                    pages,
                    offset_min=cell.spans[0].offset,
                    target=first_cell_word_text,
                )

                if not first_cell_word_object:
                    print(
                        f"\t\t- {cell.row_index}: {cell.content} [NONE px] ({first_cell_word_text}, span {cell.spans[0].offset})"
                    )

                    first_cell_polygon = cell.bounding_regions[0].polygon

                    first_position_x = first_point_x_pixels(
                        first_cell_polygon, unit="pixel", dpi=96
                    )

                    table_rebuilt.table_rows[-1].cells.append(
                        Cell(
                            row_index=cell.row_index,
                            column_index=cell.column_index,
                            content=cell.content,
                            offset_span=cell.spans[0].offset,
                            span_len=cell.spans[0].length,  # ←
                            offset_px=first_position_x,
                            polygon=first_cell_polygon,
                        )
                    )

                    continue

                else:
                    first_cell_polygon = (
                        first_cell_word_object.polygon if table.cells else None
                    )

                    first_position_x = first_point_x_pixels(
                        first_cell_polygon, unit="pixel", dpi=96
                    )

                    print(
                        f"\t\t- {cell.row_index}: {cell.content} [{first_position_x} px] ({first_cell_word_text}, span {cell.spans[0].offset})"
                    )

                table_rebuilt.table_rows[-1].cells.append(
                    Cell(
                        row_index=cell.row_index,
                        column_index=cell.column_index,
                        content=cell.content,
                        offset_span=cell.spans[0].offset if cell.spans else 0,
                        span_len=cell.spans[0].length if cell.spans else 0,
                        offset_px=first_position_x,
                        polygon=cell.bounding_regions[0].polygon,
                    )
                )

        table_row.line_styles = _styles_for_row(table_row, styles)

        for row in table_rebuilt.table_rows:
            row.line_styles = _styles_for_row(row, styles)

        if table_rebuilt.table_rows:
            tables_rebuilt.append(table_rebuilt)

    for table in tables_rebuilt:
        for row in table.table_rows:
            row_font_pt = estimate_row_height_px(row=row, pages=pages)

            # row_font_pt = round(row_font_pt, 0)

            # print(f"Ligne {row.row_index} : ~{row_font_pt:.1f} pt")
            # vous pouvez aussi stocker la valeur dans row.line_styles, par ex.:
            row.line_styles.append(LineStyle(font_size=row_font_pt))

    # for table in tables_rebuilt:
    #     table.print_table()

    all_font_size = set()

    all_bg_color = set()

    all_color = set()

    all_font_family = set()

    all_font_weight = set()

    all_font_style = set()

    for table in tables_rebuilt:
        for row in table.table_rows:
            for cell in row.cells:
                for style in row.line_styles:
                    if style.font_size is not None:
                        all_font_size.add(style.font_size)
                    if style.color is not None:
                        all_color.add(style.color)
                    if style.font_family is not None:
                        all_font_family.add(style.font_family)
                    if style.font_weight is not None:
                        all_font_weight.add(style.font_weight)
                    if style.font_style is not None:
                        all_font_style.add(style.font_style)
                    if style.background_color is not None:
                        all_bg_color.add(style.background_color)

    print(f"\n# FOUNDING TABLES STYLES\n")
    print(f"## Font Sizes: {all_font_size}")
    print(f"## Background Colors: {all_bg_color}")
    print(f"## Text Colors: {all_color}")
    print(f"## Font Families: {all_font_family}")
    print(f"## Font Weights: {all_font_weight}")
    print(f"## Font Styles: {all_font_style}")

    bg2icon = assign_icons(all_bg_color, threshold=10.0)  # <- ①
    print(f"## BG → icon mapping : {bg2icon}")  # debug

    return tables_rebuilt, ranges, bg2icon


def build_document_text(
    paragraphs: List[DocumentParagraph],
    tables: List[DocumentTable],
    pages: List[DocumentPage],
    styles: List[DocumentStyle],
) -> str:
    """
    Reconstruit le document (paragraphes + tableaux) et renvoie **une seule
    chaîne** où chaque élément est sur sa propre ligne.

    Le contenu des tables est formaté avec les mêmes règles d’alignement que
    dans votre fonction `Table.print_table()`.
    """
    # 1) tables reconstruites + leurs plages de spans
    tables_built, tbl_ranges, bg2icon = rebuilt_tables(tables, pages, styles)

    assign_h_levels(tables_built)

    print("\nDEBUG – premières cellules et tailles mesurées")
    for t in tables_built:
        for row in t.table_rows:
            fs = next((s.font_size for s in row.line_styles if s.font_size), 0.0)
            first_txt = row.cells[0].content.strip() if row.cells else ""
            print(
                f"  h{row.level_h} | {fs:4.3f} pt | {first_txt[:60]} | polygone {row.cells[0].polygon if row.cells else 'None'} | word use for size {row.cells[0].word_used_for_size if row.cells else 'None'}"
            )
    print("--- fin debug ---\n")

    # 2) flux unifié (offset, kind, obj)
    items: List[Tuple[int, str, object]] = []

    for p in paragraphs:
        if p.spans and _overlaps(p.spans[0].offset, p.spans[0].length, tbl_ranges):
            continue  # paragraphe « dans » une table
        # items.append((_para_offset(p), "para", p))

    for t in tables_built:
        items.append((t.offset_span, "table", t))

    items.sort(key=lambda x: x[0])  # ordre de lecture

    # 3) accumulation dans un buffer mémoire
    buf = io.StringIO()

    for _, kind, obj in items:
        if kind == "para":
            buf.write(obj.content.strip() + "\n")
        else:  # table
            # — réutilise le code d’affichage existant —
            max_level = max(r.level_h for r in obj.table_rows) or 5
            col_off = obj._col_offset_max()
            col_w = _table_col_widths(obj, col_off, max_level, bg2icon)

            for row in obj.table_rows:
                parts = [" " * col_w[i] for i in range(len(col_w))]
                for c in row.cells:
                    i = c.column_index
                    indent = (
                        int(c.offset_px * MULT)
                        if i == 0
                        else int(max(0, c.offset_px - col_off[i - 1]) * MULT)
                    )
                    cell_txt = (
                        _first_cell_text(row, c.content, max_level, bg2icon)
                        if i == 0
                        else c.content
                    )
                    parts[i] = (" " * indent + cell_txt).ljust(col_w[i])
                buf.write(SEP.join(parts).rstrip() + "\n")
            buf.write("\n")

    return buf.getvalue()


doc_txt = build_document_text(
    paragraphs=paragraphs or [],
    tables=tables or [],
    pages=pages or [],
    styles=styles or [],
)

print("\n\n\n\n\n####################\n\n\n\n\n")

print(doc_txt)


a_out = Path(proposal_path.proposal_html_path)

a_out.parent.mkdir(parents=True, exist_ok=True)

a_out.write_text(doc_txt, encoding="utf-8")

print(f"✅ Proposal text written to {a_out.resolve()}")
# Out:
# # FOUNDING TABLES SPANS
#
# There are 13 tables
# Table spans: 483 - 2012 [Désignation]
# 	- Nombre lignes: 4
# 	- Nombre colonnes: 5
# 		- 0: Désignation [2.5446 px] (Désignation, span 500)
# 		- 0: Qté [5.6243 px] (Qté, span 521)
# 		- 0: Pu HT [6.173 px] (Pu, span 534)
# 		- 0: Total HT [6.83 px] (Total, span 549)
# 		- 0: TVA [7.5303 px] (TVA, span 567)
# 		- 1: Entrée : Porte circulaire . - Châssis unique version CIRCULAR plaque de plâtre rayon 1200 ouverture à droite pour porte de LP=830 HP=2040 mm - Porte + Habillage + Couvre-joints unique version CIRCULAR plaqué Tanganika rayon 1200 ouverture à droite pour porte de LP= 830 HP=2040 mm - Kiit AGB RONDO (serrure condamnation/decondamnation) finition Chromé Satiné pour porte coulissante bois (épr 40 mm) . SOUSRESERVE D'UN DESCRIPTIF TECHNIQUE PLUS PRECIS POUR ADAPTER AU BESOIN CLIENT [0.4785 px] (Entrée, span 591)
# 		- 1: 1 [5.7118 px] (1, span 1081)
# 		- 1: 3 829,44 € [6.0781 px] (3, span 1092)
# 		- 1: 3 829,44 € [6.8275 px] (3, span 1112)
# 		- 1: 20 % [7.5207 px] (20, span 1132)
# 		- 2: Cellier : Porte Plane Kreation - Ame pleine Haut 2040 mm x Larg 830 mm . Porte ferrée pour Clypso Kreation . 1 vantail . Chants droits . Coloris : M05 Chêne d'Orleans Taupe . Charnières invisibles . Joint en traverse basse : 1 lèvre non coupe feu . Serrure PD 1/2 tour magnétique axe à 50 mm . Gauche poussant . Avec emballage Dont éco-contribution REP PMCB : 1,18€ HT Fabrication française [0.4759 px] (Cellier, span 1157)
# 		- 2: 1 [5.7151 px] (1, span 1557)
# 		- 2: 210,33 € [NONE px] (210,33 €, span 1568)
# 		- 2: 210,33 € [NONE px] (210,33 €, span 1586)
# 		- 2: 20 % [7.5222 px] (20, span 1604)
# 		- 3: Cellier : CLYPSO KREATION pour mur de 71 à 98 mm (nº1) Haut 2040 mm x Larg 830 mm . Pour porte Pleinitude . Chants droits . Charnières invisibles . Gâche pour serrure 1 pt magnétique . Coloris : M05 Chêne d'Orleans Taupe . Gauche poussant Dont éco-contribution REP PMCB : 0,17€ HT Fabrication française [0.4769 px] (Cellier, span 1629)
# 		- 3: 1 [5.7149 px] (1, span 1941)
# 		- 3: 281,08 € [NONE px] (281,08 €, span 1952)
# 		- 3: 281,08 € [NONE px] (281,08 €, span 1970)
# 		- 3: 20 % [7.5217 px] (20, span 1988)
# Table spans: 2613 - 4847 [Désignation]
# 	- Nombre lignes: 13
# 	- Nombre colonnes: 5
# 		- 0: Désignation [2.5473 px] (Désignation, span 2630)
# 		- 0: Qté [5.6279 px] (Qté, span 2651)
# 		- 0: Pu HT [6.1763 px] (Pu, span 2664)
# 		- 0: Total HT [6.8308 px] (Total, span 2679)
# 		- 0: TVA [7.5309 px] (TVA, span 2697)
# 		- 1: Cellier : Béquille B01 Inox PDDT [0.4771 px] (Cellier, span 2721)
# 		- 1: 1 [5.7132 px] (1, span 2763)
# 		- 1: 47,88 € [NONE px] (47,88 €, span 2774)
# 		- 1: 47,88 € [NONE px] (47,88 €, span 2791)
# 		- 1: 20 % [7.5223 px] (20, span 2808)
# 		- 2: Dont éco-contribution REP PMCB : 0,01€ HT 0
# finition INOX
# B01 [1.736 px] (Dont, span 2833)
# 		- 3: Dégagement 2 : Porte Plane Kreation - Ame pleine Haut 2040 mm x Larg 830 mm [0.4802 px] (Dégagement, span 2955)
# 		- 3: 1 [5.7145 px] (1, span 3040)
# 		- 3: 210,33 € [NONE px] (210,33 €, span 3051)
# 		- 3: 210,33 € [NONE px] (210,33 €, span 3081)
# 		- 3: 20 % [7.5212 px] (20, span 3099)
# 		- 4: . Porte ferree pour Clypso Kreation . 1 vantail . Chants droits . Coloris : M05 Chêne d'Orleans Taupe . Charnières invisibles . Joint en traverse basse : 1 lèvre non coupe feu . Serrure PD 1/2 tour magnétique axe à 50 mm . Droite poussant . Avec emballage Dont éco-contribution REP PMCB : 1,18€ HT Fabrication française [1.8805 px] (Porte, span 3124)
# 		- 5: Dégagement 2 : CLYPSO KREATION pour mur de 71 à 98 mm (nº1) Haut 2040 mm x Larg 830 mm [0.4795 px] (Dégagement, span 3494)
# 		- 5: 1 [5.7159 px] (1, span 3590)
# 		- 5: 281,08 € [NONE px] (281,08 €, span 3613)
# 		- 5: 281,08 € [NONE px] (281,08 €, span 3643)
# 		- 5: 20 % [7.5235 px] (20, span 3661)
# 		- 6: . Pour porte Pleinitude . Chants droits [1.8801 px] (Pour, span 3698)
# 		- 8: . Charnières invisibles . Gâche pour serrure 1 pt magnétique . Coloris : M05 Chêne d'Orleans Taupe . Droite poussant Dont éco-contribution REP PMCB : 0,17€ HT Fabrication française [1.8763 px] (Charnières, span 3819)
# 		- 9: Dégagement 2 : Béquille B01 Inox PDDT [0.48 px] (Dégagement, span 4060)
# 		- 9: 1 [5.716 px] (1, span 4119)
# 		- 9: 47,88 € [NONE px] (47,88 €, span 4142)
# 		- 9: 47,88 € [NONE px] (47,88 €, span 4171)
# 		- 9: 20 % [7.5234 px] (20, span 4200)
# 		- 10: Dont éco-contribution REP PMCB : 0,01€ HT O
# finition INOX
# B01 [1.736 px] (Dont, span 4225)
# 		- 11: Salle de musique : Porte Plane Kreation - Ame pleine Haut 2040 mm x Larg 830 mm [0.4744 px] (Salle, span 4307)
# 		- 11: 1 [5.7168 px] (1, span 4396)
# 		- 11: 210,33 € [NONE px] (210,33 €, span 4407)
# 		- 11: 210,33 € [NONE px] (210,33 €, span 4425)
# 		- 11: 20 % [7.5218 px] (20, span 4443)
# 		- 12: . Porte ferrée pour Clypso Kreation . 1 vantail . Chants droits . Coloris : M05 Chêne d'Orleans Taupe . Charnières invisibles . Joint en traverse basse : 1 lèvre non coupe feu . Serrure PD 1/2 tour magnétique axe à 50 mm . Gauche poussant . Avec emballage Dont éco-contribution REP PMCB : 1,18€ HT Fabrication française [1.8812 px] (Porte, span 4468)
# Table spans: 5490 - 7281 [Désignation]
# 	- Nombre lignes: 9
# 	- Nombre colonnes: 5
# 		- 0: Désignation [2.5478 px] (Désignation, span 5507)
# 		- 0: Qté [5.6279 px] (Qté, span 5528)
# 		- 0: Pu HT [6.1762 px] (Pu, span 5541)
# 		- 0: Total HT [6.831 px] (Total, span 5556)
# 		- 0: TVA [7.5306 px] (TVA, span 5574)
# 		- 1: Salle de musique : CLYPSO KREATION pour mur de 71 à 98 mm (nº1) Haut 2040 mm x Larg 830 mm . Pour porte Pleinitude . Chants droits . Charnières invisibles . Gâche pour serrure 1 pt magnétique . Coloris : M05 Chêne d'Orleans Taupe . Gauche poussant Dont éco-contribution REP PMCB : 0,17€ HT Fabrication française [0.4765 px] (Salle, span 5610)
# 		- 1: 1 [5.7135 px] (1, span 5931)
# 		- 1: 281,08 € [NONE px] (281,08 €, span 5942)
# 		- 1: 281,08 € [NONE px] (281,08 €, span 5960)
# 		- 1: 20 % [7.5212 px] (20, span 5978)
# 		- 3: Salle de musique : Béquille B01 Inox PDDT Dont éco-contribution REP PMCB : 0,01€ HT O B01 finition INOX [0.4752 px] (Salle, span 6054)
# 		- 3: 1 [5.7151 px] (1, span 6167)
# 		- 3: 47,88 € [NONE px] (47,88 €, span 6178)
# 		- 3: 47,88 € [NONE px] (47,88 €, span 6195)
# 		- 3: 20 % [7.5231 px] (20, span 6212)
# 		- 4: Dégagement 1 : Porte Plane Kreation - Ame pleine Haut 2040 mm x Larg 830 mm . Porte coulissante . 1 vantail . Chants droits . Coloris : M05 Chêne d'Orleans Taupe . Habillage pour cloison 98mm : coloris Chêne d'Orleans Taupe M05 . Entaillage serrure pour porte coulissante, cuvette + tire doigt . Sens d'ouverture à définir . Rainure en traverse basse . Avec emballage Dont éco-contribution REP PMCB : 1,35€ HT Fabrication française [0.4797 px] (Dégagement, span 6249)
# 		- 4: 1 [5.7161 px] (1, span 6690)
# 		- 4: 469,22 € [NONE px] (469,22 €, span 6701)
# 		- 4: 469,22 € [NONE px] (469,22 €, span 6719)
# 		- 4: 20 % [7.5233 px] (20, span 6737)
# 		- 7: Dégagement 1 : CHASSIS ECLISSE 95 Châssis eclisse 95 UNIQUE pour Plaques de plâtre, Epaisseur cloison finie de 95 mm, version prémontée compris châssis métallique [0.4812 px] (Dégagement, span 6864)
# 		- 7: 1 [5.7153 px] (1, span 7036)
# 		- 7: 399,50 € [NONE px] (399,50 €, span 7047)
# 		- 7: 399,50 € [NONE px] (399,50 €, span 7065)
# 		- 7: 20 % [7.5239 px] (20, span 7083)
# 		- 8: Dégagement 1 : GARNITURE SANS SERRURE GARNITURE CHROME SATINE SANS SERRURE SANS PLAQUE TETIERE [0.4796 px] (Dégagement, span 7108)
# 		- 8: 1 [5.7148 px] (1, span 7212)
# 		- 8: 27,00 € [NONE px] (27,00 €, span 7223)
# 		- 8: 27,00 € [NONE px] (27,00 €, span 7240)
# 		- 8: 20 % [7.5237 px] (20, span 7257)
# Table spans: 7927 - 9798 [Désignation]
# 	- Nombre lignes: 9
# 	- Nombre colonnes: 5
# 		- 0: Désignation [2.548 px] (Désignation, span 7944)
# 		- 0: Qté [5.6279 px] (Qté, span 7965)
# 		- 0: Pu HT [6.1759 px] (Pu, span 7978)
# 		- 0: Total HT [6.8307 px] (Total, span 7993)
# 		- 0: TVA [7.5305 px] (TVA, span 8011)
# 		- 1: Toilettes 2 : Porte Plane Kreation - Ame pleine [0.4721 px] (Toilettes, span 8035)
# 		- 1: 1 [5.7135 px] (1, span 8092)
# 		- 1: 210,33 € [NONE px] (210,33 €, span 8103)
# 		- 1: 210,33 € [NONE px] (210,33 €, span 8121)
# 		- 1: 20 % [7.5214 px] (20, span 8139)
# 		- 2: Haut 2040 mm x Larg 830 mm . Porte ferree pour Clypso Kreation . 1 vantail . Chants droits . Coloris : M05 Chêne d'Orleans Taupe . Charnières invisibles . Joint en traverse basse : 1 lèvre non coupe feu Serrure Bec de cane à condamnation magnétique axe à 50 mm . Droite poussant . Avec emballage Dont éco-contribution REP PMCB : 1,18€ HT Fabrication française [0.4767 px] (Haut, span 8176)
# 		- 4: Toilettes 2 : CLYPSO KREATION pour mur de 71 à 98 mm (nº1) Haut 2040 mm x Larg 830 mm . Pour porte Pleinitude . Chants droits . Charnières invisibles . Gâche pour serrure 1 pt magnétique . Coloris : M05 Chêne d'Orleans Taupe . Droite poussant Dont éco-contribution REP PMCB : 0,17€ HT Fabrication française [0.4745 px] (Toilettes, span 8647)
# 		- 4: 1 [5.715 px] (1, span 8963)
# 		- 4: 281,08 € [NONE px] (281,08 €, span 8974)
# 		- 4: 281,08 € [NONE px] (281,08 €, span 8992)
# 		- 4: 20 % [7.5232 px] (20, span 9010)
# 		- 5: Toilettes 2 : Béquille B01 Inox BCC Dont éco-contribution REP PMCB : 0,01€ HT O
# finition INOX
# B01 [0.4736 px] (Toilettes, span 9035)
# 		- 5: 1 [5.7168 px] (1, span 9142)
# 		- 5: 68,58 € [NONE px] (68,58 €, span 9153)
# 		- 5: 68,58 € [NONE px] (68,58 €, span 9170)
# 		- 5: 20 % [7.5242 px] (20, span 9187)
# 		- 6: Dressing : Porte Plane Kreation - Ame pleine Haut 2040 mm x Larg 830 mm . Porte ferree pour Clypso Kreation . 1 vantail . Chants droits . Coloris : M05 Chêne d'Orleans Taupe . Charnières invisibles . Joint en traverse basse : 1 lèvre non coupe feu . Serrure PD 1/2 tour magnétique axe à 50 mm . Gauche poussant . Avec emballage Dont éco-contribution REP PMCB : 1,18€ HT Fabrication française [0.4811 px] (Dressing, span 9224)
# 		- 6: 1 [5.716 px] (1, span 9625)
# 		- 6: 210,33 € [NONE px] (210,33 €, span 9636)
# 		- 6: 210,33 € [NONE px] (210,33 €, span 9654)
# 		- 6: 20 % [7.5234 px] (20, span 9672)
# Table spans: 10444 - 12816 [Désignation]
# 	- Nombre lignes: 17
# 	- Nombre colonnes: 5
# 		- 0: Désignation [2.5474 px] (Désignation, span 10461)
# 		- 0: Qté [5.628 px] (Qté, span 10482)
# 		- 0: Pu HT [6.176 px] (Pu, span 10495)
# 		- 0: Total HT [6.8305 px] (Total, span 10510)
# 		- 0: TVA [7.53 px] (TVA, span 10528)
# 		- 1: Dressing : CLYPSO KREATION pour mur de 71 à 98 mm (nº1) Haut 2040 mm x Larg 830 mm [0.4814 px] (Dressing, span 10552)
# 		- 1: 1 [5.7135 px] (1, span 10644)
# 		- 1: 281,08 € [NONE px] (281,08 €, span 10655)
# 		- 1: 281,08 € [NONE px] (281,08 €, span 10673)
# 		- 1: 20 % [7.5205 px] (20, span 10691)
# 		- 2: . Pour porte Pleinitude . Chants droits . Charnières invisibles . Gâche pour serrure 1 pt magnétique . Coloris : M05 Chêne d'Orleans Taupe . Gauche poussant Dont éco-contribution REP PMCB : 0,17€ HT Fabrication française [1.8805 px] (Pour, span 10728)
# 		- 4: Dressing : Béquille B01 Inox PDDT [0.4794 px] (Dressing, span 11060)
# 		- 4: 1 [5.7151 px] (1, span 11103)
# 		- 4: 47,88 € [NONE px] (47,88 €, span 11114)
# 		- 4: 47,88 € [NONE px] (47,88 €, span 11131)
# 		- 4: 20 % [7.5227 px] (20, span 11148)
# 		- 5: Dont éco-contribution REP PMCB : 0,01€ HT O
# finition INOX
# B01 [1.7372 px] (Dont, span 11185)
# 		- 7: Chambre 1 : Porte Plane Kreation - Ame pleine [0.4785 px] (Chambre, span 11364)
# 		- 7: 1 [5.7163 px] (1, span 11419)
# 		- 7: 210,33 € [NONE px] (210,33 €, span 11430)
# 		- 7: 210,33 € [NONE px] (210,33 €, span 11448)
# 		- 7: 20 % [7.5228 px] (20, span 11466)
# 		- 8: Haut 2040 mm x Larg 830 mm . Porte ferrée pour Clypso Kreation . 1 vantail . Chants droits . Coloris : M05 Chêne d'Orleans Taupe . Charnières invisibles . Joint en traverse basse : 1 lèvre non coupe feu . Serrure PD 1/2 tour magnétique axe à 50 mm . Droite poussant . Avec emballage Dont éco-contribution REP PMCB : 1,18€ HT Fabrication française [0.4779 px] (Haut, span 11503)
# 		- 11: Chambre 1 : CLYPSO KREATION pour mur de 71 à 98 mm (nº1) Haut 2040 mm x Larg 830 mm [0.4794 px] (Chambre, span 12012)
# 		- 11: 1 [5.7156 px] (1, span 12105)
# 		- 11: 281,08 € [NONE px] (281,08 €, span 12116)
# 		- 11: 281,08 € [NONE px] (281,08 €, span 12134)
# 		- 11: 20 % [7.5227 px] (20, span 12152)
# 		- 12: . Pour porte Pleinitude [1.8801 px] (Pour, span 12177)
# 		- 13: . Chants droits . Charnières invisibles . Gâche pour serrure 1 pt magnétique . Coloris : M05 Chêne d'Orleans Taupe . Droite poussant Dont éco-contribution REP PMCB : 0,17€ HT Fabrication française [1.8752 px] (Chants, span 12273)
# 		- 15: Chambre 1 : Béquille B01 Inox PDDT [0.4775 px] (Chambre, span 12581)
# 		- 15: 1 [5.7159 px] (1, span 12625)
# 		- 15: 47,88 € [NONE px] (47,88 €, span 12636)
# 		- 15: 47,88 € [NONE px] (47,88 €, span 12653)
# 		- 15: 20 % [7.5234 px] (20, span 12670)
# 		- 16: Dont éco-contribution REP PMCB : 0,01€ HT O
# finition INOX
# B01 [1.7381 px] (Dont, span 12695)
# Table spans: 13483 - 15426 [Désignation]
# 	- Nombre lignes: 10
# 	- Nombre colonnes: 5
# 		- 0: Désignation [2.5476 px] (Désignation, span 13500)
# 		- 0: Qté [5.6275 px] (Qté, span 13521)
# 		- 0: Pu HT [6.1756 px] (Pu, span 13534)
# 		- 0: Total HT [6.8306 px] (Total, span 13549)
# 		- 0: TVA [7.5304 px] (TVA, span 13567)
# 		- 1: Chambre 2 : Porte Plane Kreation - Ame pleine [0.4778 px] (Chambre, span 13591)
# 		- 1: 1 [5.7133 px] (1, span 13646)
# 		- 1: 210,33 € [NONE px] (210,33 €, span 13657)
# 		- 1: 210,33 € [NONE px] (210,33 €, span 13675)
# 		- 1: 20 % [7.5213 px] (20, span 13693)
# 		- 2: Haut 2040 mm x Larg 830 mm . Porte ferrée pour Clypso Kreation . 1 vantail . Chants droits . Coloris : M05 Chêne d'Orleans Taupe . Charnières invisibles . Joint en traverse basse : 1 lèvre non coupe feu . Serrure PD 1/2 tour magnétique axe à 50 mm . Gauche poussant . Avec emballage Dont éco-contribution REP PMCB : 1,18€ HT Fabrication française [0.4764 px] (Haut, span 13730)
# 		- 4: Chambre 2 : CLYPSO KREATION pour mur de 71 à 98 mm (nº1) Haut 2040 mm x Larg 830 mm [0.4794 px] (Chambre, span 14188)
# 		- 4: 1 [5.7145 px] (1, span 14281)
# 		- 4: 281,08 € [NONE px] (281,08 €, span 14292)
# 		- 4: 281,08 € [NONE px] (281,08 €, span 14310)
# 		- 4: 20 % [7.523 px] (20, span 14328)
# 		- 5: . Pour porte Pleinitude . Chants droits . Charnières invisibles . Gâche pour serrure 1 pt magnétique . Coloris : M05 Chêne d'Orleans Taupe . Gauche poussant Dont éco-contribution REP PMCB : 0,17€ HT Fabrication française [1.8802 px] (Pour, span 14353)
# 		- 6: Chambre 2 : Béquille B01 Inox PDDT [0.478 px] (Chambre, span 14634)
# 		- 6: 1 [5.7159 px] (1, span 14678)
# 		- 6: 47,88 € [NONE px] (47,88 €, span 14689)
# 		- 6: 47,88 € [NONE px] (47,88 €, span 14718)
# 		- 6: 20 % [7.5239 px] (20, span 14747)
# 		- 7: Dont éco-contribution REP PMCB : 0,01€ HT O
# finition INOX
# B01 [1.7368 px] (Dont, span 14772)
# 		- 8: Salle d'eau 1 : Porte Plane Kreation - Ame pleine Haut 2040 mm x Larg 830 mm [0.4745 px] (Salle, span 14874)
# 		- 8: 1 [5.7152 px] (1, span 14960)
# 		- 8: 210,33 € [NONE px] (210,33 €, span 14971)
# 		- 8: 210,33 € [NONE px] (210,33 €, span 14989)
# 		- 8: 20 % [7.5231 px] (20, span 15007)
# 		- 9: . Porte ferrée pour Clypso Kreation . 1 vantail . Chants droits . Coloris : M05 Chêne d'Orleans Taupe . Charnières invisibles . Joint en traverse basse : 1 lèvre non coupe feu . Serrure Bec de cane à condamnation magnétique axe à 50 mm . Gauche poussant . Avec emballage Dont éco-contribution REP PMCB : 1,18€ HT Fabrication française [1.882 px] (Porte, span 15032)
# Table spans: 16051 - 18411 [Désignation]
# 	- Nombre lignes: 20
# 	- Nombre colonnes: 5
# 		- 0: Désignation [2.5477 px] (Désignation, span 16068)
# 		- 0: Qté [5.6281 px] (Qté, span 16089)
# 		- 0: Pu HT [6.1764 px] (Pu, span 16102)
# 		- 0: Total HT [6.8311 px] (Total, span 16117)
# 		- 0: TVA [7.5305 px] (TVA, span 16135)
# 		- 1: Salle d'eau 1 : CLYPSO KREATION pour mur de 71 à 98 mm (nº1) [0.4762 px] (Salle, span 16159)
# 		- 1: 1 [5.7139 px] (1, span 16229)
# 		- 1: 281,08 € [NONE px] (281,08 €, span 16240)
# 		- 1: 281,08 € [NONE px] (281,08 €, span 16258)
# 		- 1: 20 % [7.5212 px] (20, span 16276)
# 		- 2: Haut 2040 mm x Larg 830 mm . Pour porte Pleinitude . Chants droits . Charnières invisibles . Gâche pour serrure 1 pt magnétique . Coloris : M05 Chêne d'Orleans Taupe . Gauche poussant Dont éco-contribution REP PMCB : 0,17€ HT Fabrication française [0.4795 px] (Haut, span 16313)
# 		- 7: Salle d'eau 1 : Béquille B01 Inox BCC [0.4756 px] (Salle, span 16791)
# 		- 7: 1 [5.7159 px] (1, span 16838)
# 		- 7: 68,58 € [NONE px] (68,58 €, span 16849)
# 		- 7: 68,58 € [NONE px] (68,58 €, span 16866)
# 		- 7: 20 % [7.5229 px] (20, span 16883)
# 		- 8: Dont éco-contribution REP PMCB : 0,01€ HT O
# finition INOX
# B01 [1.7378 px] (Dont, span 16920)
# 		- 10: Bureau : Porte Plane Kreation - Ame pleine [0.481 px] (Bureau, span 17095)
# 		- 10: 1 [5.7169 px] (1, span 17147)
# 		- 10: 469,22 € [NONE px] (469,22 €, span 17158)
# 		- 10: 469,22 € [NONE px] (469,22 €, span 17176)
# 		- 10: 20 % [7.5232 px] (20, span 17194)
# 		- 11: Haut 2040 mm x Larg 830 mm . Porte coulissante . 1 vantail . Chants droits . Coloris : M05 Chêne d'Orleans Taupe . Habillage pour cloison 98mm : coloris Chêne d'Orleans Taupe M05 . Entaillage serrure pour porte coulissante, mortaise + cuvette + tire doigt . Sens d'ouverture à définir . Rainure en traverse basse . Avec emballage Dont éco-contribution REP PMCB : 1,35€ HT Fabrication française [0.4793 px] (Haut, span 17231)
# 		- 15: Bureau : CHASSIS ECLISSE 95 Châssis eclisse 95 UNIQUE pour Plaques de plâtre, Epaisseur cloison finie de 95 mm, version prémontée compris châssis métallique [0.4817 px] (Bureau, span 17850)
# 		- 15: 1 [5.7166 px] (1, span 18016)
# 		- 15: 399,50 € [NONE px] (399,50 €, span 18039)
# 		- 15: 399,50 € [NONE px] (399,50 €, span 18069)
# 		- 15: 20 % [7.5239 px] (20, span 18087)
# 		- 17: Bureau : GARNITURE SERRURE L GARNITURE CHROME SATINE AVEC SERRURE BCC [0.4802 px] (Bureau, span 18155)
# 		- 17: 1 [5.7165 px] (1, span 18246)
# 		- 17: 50,34 € [NONE px] (50,34 €, span 18257)
# 		- 17: 50,34 € [NONE px] (50,34 €, span 18286)
# 		- 17: 20 % [7.5237 px] (20, span 18315)
# Table spans: 19057 - 21008 [Désignation]
# 	- Nombre lignes: 10
# 	- Nombre colonnes: 5
# 		- 0: Désignation [2.548 px] (Désignation, span 19074)
# 		- 0: Qté [5.6278 px] (Qté, span 19095)
# 		- 0: Pu HT [6.1759 px] (Pu, span 19108)
# 		- 0: Total HT [6.8306 px] (Total, span 19123)
# 		- 0: TVA [7.5307 px] (TVA, span 19141)
# 		- 1: Toilettes 3 : Porte Plane Kreation - Ame pleine Haut 2040 mm x Larg 830 mm . Porte ferree pour Clypso Kreation . 1 vantail . Chants droits . Coloris : M05 Chêne d'Orleans Taupe . Charnières invisibles . Joint en traverse basse : 1 lèvre non coupe feu Serrure Bec de cane à condamnation magnétique axe à 50 mm . Droite poussant . Avec emballage Dont éco-contribution REP PMCB : 1,18€ HT Fabrication française [0.4722 px] (Toilettes, span 19177)
# 		- 1: 1 [5.7134 px] (1, span 19594)
# 		- 1: 210,33 € [NONE px] (210,33 €, span 19605)
# 		- 1: 210,33 € [NONE px] (210,33 €, span 19623)
# 		- 1: 20 % [7.5216 px] (20, span 19641)
# 		- 4: Toilettes 3 : CLYPSO KREATION pour mur de 71 à 98 mm (nº1) Haut 2040 mm x Larg 830 mm . Pour porte Pleinitude . Chants droits . Charnières invisibles . Gâche pour serrure 1 pt magnétique . Coloris : M05 Chêne d'Orleans Taupe . Droite poussant Dont éco-contribution REP PMCB : 0,17€ HT Fabrication française [0.4747 px] (Toilettes, span 19768)
# 		- 4: 1 [5.7149 px] (1, span 20084)
# 		- 4: 281,08 € [NONE px] (281,08 €, span 20095)
# 		- 4: 281,08 € [NONE px] (281,08 €, span 20113)
# 		- 4: 20 % [7.5233 px] (20, span 20131)
# 		- 5: Toilettes 3 : Béquille B01 Inox BCC Dont éco-contribution REP PMCB : 0,01€ HT O B01 finition INOX [0.4736 px] (Toilettes, span 20168)
# 		- 5: 1 [5.7165 px] (1, span 20275)
# 		- 5: 68,58 € [NONE px] (68,58 €, span 20298)
# 		- 5: 68,58 € [NONE px] (68,58 €, span 20327)
# 		- 5: 20 % [7.5243 px] (20, span 20356)
# 		- 8: Salle d'eau 2 : Porte Plane Kreation - Ame pleine Haut 2040 mm x Larg 830 mm . Porte ferrée pour Clypso Kreation . 1 vantail . Chants droits . Coloris : M05 Chêne d'Orleans Taupe . Charnières invisibles . Joint en traverse basse : 1 lèvre non coupe feu . Serrure Bec de cane à condamnation magnétique axe à 50 mm . Droite poussant . Avec emballage Dont éco-contribution REP PMCB : 1,18€ HT Fabrication française [0.4749 px] (Salle, span 20465)
# 		- 8: 1 [5.7158 px] (1, span 20886)
# 		- 8: 210,33 € [NONE px] (210,33 €, span 20897)
# 		- 8: 210,33 € [NONE px] (210,33 €, span 20915)
# 		- 8: 20 % [7.5235 px] (20, span 20933)
# Table spans: 21633 - 24132 [Désignation]
# 	- Nombre lignes: 19
# 	- Nombre colonnes: 5
# 		- 0: Désignation [2.5475 px] (Désignation, span 21650)
# 		- 0: Qté [5.6279 px] (Qté, span 21671)
# 		- 0: Pu HT [6.1762 px] (Pu, span 21684)
# 		- 0: Total HT [6.8308 px] (Total, span 21699)
# 		- 0: TVA [7.53 px] (TVA, span 21717)
# 		- 1: Salle d'eau 2 : CLYPSO KREATION pour mur de 71 à 98 mm (nº1) Haut 2040 mm x Larg 830 mm [0.4761 px] (Salle, span 21741)
# 		- 1: 1 [5.7135 px] (1, span 21838)
# 		- 1: 281,08 € [NONE px] (281,08 €, span 21849)
# 		- 1: 281,08 € [NONE px] (281,08 €, span 21867)
# 		- 1: 20 % [7.5207 px] (20, span 21885)
# 		- 2: . Pour porte Pleinitude . Chants droits . Charnières invisibles . Gâche pour serrure 1 pt magnétique . Coloris : M05 Chêne d'Orleans Taupe . Droite poussant Dont éco-contribution REP PMCB : 0,17€ HT Fabrication française [1.8809 px] (Pour, span 21922)
# 		- 5: Salle d'eau 2 : Béquille B01 Inox BCC [0.4756 px] (Salle, span 22305)
# 		- 5: 1 [5.7155 px] (1, span 22352)
# 		- 5: 68,58 € [NONE px] (68,58 €, span 22363)
# 		- 5: 68,58 € [NONE px] (68,58 €, span 22380)
# 		- 5: 20 % [7.5226 px] (20, span 22397)
# 		- 6: Dont éco-contribution REP PMCB : 0,01€ HT O
# finition INOX
# B01 [1.7376 px] (Dont, span 22434)
# 		- 8: Chambre 4 : Porte Plane Kreation - Ame pleine [0.4788 px] (Chambre, span 22611)
# 		- 8: 1 [5.7163 px] (1, span 22666)
# 		- 8: 210,33 € [NONE px] (210,33 €, span 22677)
# 		- 8: 210,33 € [NONE px] (210,33 €, span 22695)
# 		- 8: 20 % [7.5229 px] (20, span 22713)
# 		- 9: Haut 2040 mm x Larg 830 mm . Porte ferree pour Clypso Kreation . 1 vantail . Chants droits . Coloris : M05 Chêne d'Orleans Taupe . Charnières invisibles . Joint en traverse basse : 1 lèvre non coupe feu . Serrure PD 1/2 tour magnétique axe à 50 mm . Gauche poussant . Avec emballage Dont éco-contribution REP PMCB : 1,18€ HT Fabrication française [0.4782 px] (Haut, span 22750)
# 		- 12: Chambre 4 : CLYPSO KREATION pour mur de 71 à 98 mm (nº1) Haut 2040 mm x Larg 830 mm [0.4795 px] (Chambre, span 23271)
# 		- 12: 1 [5.7157 px] (1, span 23376)
# 		- 12: 281,08 € [NONE px] (281,08 €, span 23399)
# 		- 12: 281,08 € [NONE px] (281,08 €, span 23429)
# 		- 12: 20 % [7.5229 px] (20, span 23447)
# 		- 14: . Pour porte Pleinitude [1.8807 px] (Pour, span 23493)
# 		- 15: . Chants droits . Charnières invisibles . Gâche pour serrure 1 pt magnétique . Coloris : M05 Chêne d'Orleans Taupe . Gauche poussant Dont éco-contribution REP PMCB : 0,17€ HT Fabrication française [1.8759 px] (Chants, span 23589)
# 		- 17: Chambre 4 : Béquille B01 Inox PDDT [0.4777 px] (Chambre, span 23897)
# 		- 17: 1 [5.7159 px] (1, span 23941)
# 		- 17: 47,88 € [NONE px] (47,88 €, span 23952)
# 		- 17: 47,88 € [NONE px] (47,88 €, span 23969)
# 		- 17: 20 % [7.5232 px] (20, span 23986)
# 		- 18: Dont éco-contribution REP PMCB : 0,01€ HT O
# finition INOX
# B01 [1.7382 px] (Dont, span 24011)
# Table spans: 24798 - 26610 [Désignation]
# 	- Nombre lignes: 11
# 	- Nombre colonnes: 5
# 		- 0: Désignation [2.5477 px] (Désignation, span 24815)
# 		- 0: Qté [5.6276 px] (Qté, span 24836)
# 		- 0: Pu HT [6.1757 px] (Pu, span 24849)
# 		- 0: Total HT [6.8305 px] (Total, span 24864)
# 		- 0: TVA [7.5304 px] (TVA, span 24882)
# 		- 1: Chambre 3 : Porte Plane Kreation - Ame pleine Haut 2040 mm x Larg 830 mm . Porte ferrée pour Clypso Kreation . 1 vantail . Chants droits . Coloris : M05 Chêne d'Orleans Taupe . Charnières invisibles . Joint en traverse basse : 1 lèvre non coupe feu Serrure PD 1/2 tour magnétique axe à 50 mm . Droite poussant . Avec emballage Dont éco-contribution REP PMCB : 1,18€ HT Fabrication française [0.478 px] (Chambre, span 24918)
# 		- 1: 1 [5.7134 px] (1, span 25330)
# 		- 1: 210,33 € [NONE px] (210,33 €, span 25341)
# 		- 1: 210,33 € [NONE px] (210,33 €, span 25371)
# 		- 1: 20 % [7.5213 px] (20, span 25389)
# 		- 4: Chambre 3 : CLYPSO KREATION pour mur de 71 à 98 mm (nº1) Haut 2040 mm x Larg 830 mm [0.4797 px] (Chambre, span 25498)
# 		- 4: 1 [5.7152 px] (1, span 25603)
# 		- 4: 281,08 € [NONE px] (281,08 €, span 25614)
# 		- 4: 281,08 € [NONE px] (281,08 €, span 25644)
# 		- 4: 20 % [7.523 px] (20, span 25674)
# 		- 5: . Pour porte Pleinitude . Chants droits . Charnières invisibles . Gâche pour serrure 1 pt magnétique . Coloris : M05 Chêne d'Orleans Taupe . Droite poussant Dont éco-contribution REP PMCB : 0,17€ HT Fabrication française [1.8805 px] (Pour, span 25711)
# 		- 7: Chambre 3 : Béquille B01 Inox PDDT Dont éco-contribution REP PMCB : 0,01€ HT O
# finition INOX
# B01 [0.4782 px] (Chambre, span 26013)
# 		- 7: 1 [5.7167 px] (1, span 26119)
# 		- 7: 47,88 € [NONE px] (47,88 €, span 26130)
# 		- 7: 47,88 € [NONE px] (47,88 €, span 26147)
# 		- 7: 20 % [7.5242 px] (20, span 26164)
# 		- 8: Pose CHASSIS CIRCULAIRE: HABILLAGES - FINITIONS (mis en place par le plaquiste) [0.481 px] (Pose, span 26189)
# 		- 8: 1 [5.7161 px] (1, span 26278)
# 		- 8: 343,88 € [NONE px] (343,88 €, span 26289)
# 		- 8: 343,88 € [NONE px] (343,88 €, span 26307)
# 		- 8: 20 % [7.5237 px] (20, span 26325)
# 		- 9: Pose des huisseries et des portes en fin de chantier avec pose des poignées et réglage [0.4784 px] (Pose, span 26350)
# 		- 9: 1 [5.7158 px] (1, span 26446)
# 		- 9: 2 200,80 € [6.0816 px] (2, span 26457)
# 		- 9: 2 200,80 € [6.8309 px] (2, span 26477)
# 		- 9: 20 % [7.5229 px] (20, span 26497)
# 		- 10: Compris: contrôle avant pose [1.7363 px] (Compris:, span 26522)
# Table spans: 27237 - 27405 [Désignation]
# 	- Nombre lignes: 2
# 	- Nombre colonnes: 5
# 		- 0: Désignation [2.5477 px] (Désignation, span 27254)
# 		- 0: Qté [5.6273 px] (Qté, span 27275)
# 		- 0: Pu HT [6.175 px] (Pu, span 27288)
# 		- 0: Total HT [6.8312 px] (Total, span 27303)
# 		- 0: TVA [7.5325 px] (TVA, span 27321)
# Table spans: 27481 - 27737 [Détail TVA]
# 	- Nombre lignes: 3
# 	- Nombre colonnes: 4
# 		- 0: Détail TVA [0.4588 px] (Détail, span 27498)
# 		- 0: 20 % [1.9558 px] (20, span 27518)
# 		- 0: 10 % [2.9034 px] (10, span 27532)
# 		- 0: 5,5 % [3.8304 px] (5,5, span 27546)
# 		- 1: Base HT [0.4595 px] (Base, span 27572)
# 		- 1: 14 743, 18 € [1.8439 px] (14, span 27589)
# 		- 1: 0,00 € [NONE px] (0,00 €, span 27611)
# 		- 1: 0,00 € [NONE px] (0,00 €, span 27627)
# 		- 2: Montant TVA [0.4574 px] (Montant, span 27654)
# 		- 2: 2 948,64 € [1.8666 px] (2, span 27675)
# 		- 2: 0,00 € [NONE px] (0,00 €, span 27695)
# 		- 2: 0,00 € [NONE px] (0,00 €, span 27711)
# Table spans: 27740 - 27913 [Total HT :]
# 	- Nombre lignes: 3
# 	- Nombre colonnes: 2
# 		- 0: Total HT : [5.5679 px] (Total, span 27757)
# 		- 0: 14 743,18 € [7.0349 px] (14, span 27777)
# 		- 1: Total TVA : [5.4924 px] (Total, span 27809)
# 		- 1: 2 948,64 € [7.1032 px] (2, span 27830)
# 		- 2: Total TTC : [5.4377 px] (Total, span 27861)
# 		- 2: 17 691,82 € [6.9301 px] (17, span 27882)
#
# # FOUNDING TABLES STYLES
#
# ## Font Sizes: {11.971200000000003, 12.777599999999978, 13.9392, 14.092800000000025, 13.200000000000017, 13.785600000000017, 14.361599999999996, 15.072000000000003, 13.775999999999954, 13.468799999999987, 15.177600000000002, 15.360000000000014, 14.630399999999966, 15.254400000000004, 14.668800000000005, 11.558400000000006, 11.356799999999964, 11.702400000000011, 11.78879999999998, 11.711999999999989, 12.460799999999992, 12.5856, 12.307199999999966, 12.921600000000069, 12.62400000000008, 13.478400000000008, 13.468800000000073, 13.228800000000014, 13.094399999999986, 13.651199999999989, 14.870399999999961, 14.159999999999997, 14.025599999999969, 14.284800000000047, 13.95839999999987, 15.043200000000006, 14.457599999999985, 14.93760000000006, 14.572799999999972, 14.543999999999997, 13.987200000000144, 15.0912, 15.4848, 14.45760000000007, 13.967999999999975, 12.10560000000001, 12.537600000000026, 12.892800000000008, 12.652800000000013, 13.536000000000001, 13.08480000000003, 11.327999999999946, 11.740800000000007, 14.83200000000005, 11.548800000000007, 13.81439999999995, 13.488000000000028, 12.288000000000011, 14.582399999999993, 13.910399999999981, 13.603200000000015, 15.139200000000006, 15.3792, 15.417599999999997, 13.33439999999996, 15.331200000000006, 12.787199999999999, 15.360000000000003, 13.891200000000026, 11.232, 13.929600000000022, 14.054399999999987, 12.547200000000004, 12.998399999999975, 13.641600000000011, 12.53759999999994, 13.238400000000013, 13.977599999999995, 11.89439999999999, 12.614400000000018, 13.689600000000006}
# ## Background Colors: {'#46464a', '#f8fafa', '#444248', '#fefefe', '#fafafa', '#424246', '#38363c', '#424248', '#f8f8f8', '#424046', '#444246', '#38343c'}
# ## Text Colors: {'#414141', '#999599', '#292929', '#616161', '#252525', '#d1cdd1', '#3d3d3d', '#9d2989', '#515151', '#090909', '#959599', '#4d4d4d', '#151515', '#a1919d', '#9d99a1', '#9d9da1', '#99959d', '#757575', '#010101', '#0d0d0d', '#313131', '#555555', '#9d999d', '#1d1d1d', '#99999d', '#2d2d2d', '#050505', '#454545', '#9d919d', '#a1959d', '#353535', '#111111', '#191919', '#a1318d', '#992185', '#c9c9cd', '#717171', '#696969', '#5d5d5d', '#992181', '#494949', '#656565', '#212121', '#595959', '#992585', '#393939', '#cdcdcd', '#cdcdd1'}
# ## Font Families: {'Arial, Helvetica, Tahoma, sans-serif', 'Tahoma, sans-serif', 'Courier New, monospace', 'Times New Roman, serif', 'Tahoma, Georgia, sans-serif', 'Segoe UI, Times New Roman, sans-serif', 'Baskerville, serif', 'Segoe UI, sans-serif', 'Tahoma, Baskerville, sans-serif', 'Arial, Helvetica, sans-serif', 'Georgia, serif', 'Tahoma, Arial, Helvetica, sans-serif', 'Tahoma, Courier New, sans-serif', 'Segoe UI, Georgia, sans-serif', 'Tahoma, Segoe UI, sans-serif', 'Tahoma, Times New Roman, sans-serif', 'Segoe UI, Tahoma, sans-serif'}
# ## Font Weights: {'bold', 'normal'}
# ## Font Styles: {'italic', 'normal'}
# ## BG → icon mapping : {'#46464a': '-', '#f8fafa': '_', '#444248': '-', '#fefefe': '_', '#fafafa': '_', '#424246': '-', '#38363c': '#', '#424248': '-', '#f8f8f8': '_', '#424046': '-', '#444246': '-', '#38343c': '#'}
#
# DEBUG – premières cellules et tailles mesurées
#   h1 | 15.360 pt | Désignation | polygone [2.5449, 3.1568, 3.3602, 3.1612, 3.3602, 3.3168, 2.5446, 3.3154] | word use for size Désignation
#   h5 | 12.778 pt | Entrée : Porte circulaire . - Châssis unique version CIRCULA | polygone [0.4787, 3.5129, 0.8804, 3.514, 0.8795, 3.6459, 0.4785, 3.646] | word use for size Entrée
#   h5 | 13.469 pt | Cellier : Porte Plane Kreation - Ame pleine Haut 2040 mm x L | polygone [0.4762, 5.4806, 0.857, 5.481, 0.8559, 5.6209, 0.4759, 5.6199] | word use for size Cellier
#   h4 | 13.776 pt | Cellier : CLYPSO KREATION pour mur de 71 à 98 mm (nº1) Haut  | polygone [0.4775, 7.7403, 0.8612, 7.7437, 0.8604, 7.8838, 0.4769, 7.8814] | word use for size Cellier
#   h2 | 15.178 pt | Désignation | polygone [2.548, 0.6519, 3.3602, 0.6559, 3.3602, 0.81, 2.5473, 0.8089] | word use for size Désignation
#   h5 | 13.478 pt | Cellier : Béquille B01 Inox PDDT | polygone [0.4777, 1.0023, 0.873, 1.0018, 0.8724, 1.1422, 0.4771, 1.1414] | word use for size Cellier
#   h5 | 11.971 pt | Dont éco-contribution REP PMCB : 0,01€ HT 0
# finition INOX
# B0 | polygone [1.7364, 1.2881, 1.9716, 1.2872, 1.9709, 1.4119, 1.736, 1.4112] | word use for size Dont
#   h3 | 14.630 pt | Dégagement 2 : Porte Plane Kreation - Ame pleine Haut 2040 m | polygone [0.4809, 2.4336, 1.2508, 2.4374, 1.2504, 2.5823, 0.4802, 2.586] | word use for size Dégagement
#   h5 | 12.106 pt | . Porte ferree pour Clypso Kreation . 1 vantail . Chants dro | polygone [1.8142, 2.7393, 1.8356, 2.7391, 1.8357, 2.8652, 1.8143, 2.8652] | word use for size .
#   h2 | 14.870 pt | Dégagement 2 : CLYPSO KREATION pour mur de 71 à 98 mm (nº1)  | polygone [0.48, 4.6939, 1.2516, 4.6984, 1.251, 4.847, 0.4795, 4.8488] | word use for size Dégagement
#   h5 | 11.712 pt | . Pour porte Pleinitude . Chants droits | polygone [1.8155, 5.0082, 1.8358, 5.0083, 1.8357, 5.1302, 1.8155, 5.1302] | word use for size .
#   h5 | 11.232 pt | . Charnières invisibles . Gâche pour serrure 1 pt magnétique | polygone [1.8155, 5.2633, 1.8351, 5.2633, 1.8354, 5.3803, 1.8158, 5.3803] | word use for size .
#   h1 | 15.254 pt | Dégagement 2 : Béquille B01 Inox PDDT | polygone [0.4809, 6.5714, 1.2501, 6.5726, 1.2494, 6.7276, 0.48, 6.7303] | word use for size Dégagement
#   h5 | 12.653 pt | Dont éco-contribution REP PMCB : 0,01€ HT O
# finition INOX
# B0 | polygone [1.7364, 6.8584, 1.9714, 6.8567, 1.9707, 6.9885, 1.736, 6.9879] | word use for size Dont
#   h4 | 13.958 pt | Salle de musique : Porte Plane Kreation - Ame pleine Haut 20 | polygone [0.4751, 8.0042, 0.7784, 8.0057, 0.7777, 8.1496, 0.4744, 8.148] | word use for size Salle
#   h5 | 12.288 pt | . Porte ferrée pour Clypso Kreation . 1 vantail . Chants dro | polygone [1.8143, 8.3123, 1.8359, 8.3121, 1.8361, 8.44, 1.8145, 8.4401] | word use for size .
#   h2 | 15.072 pt | Désignation | polygone [2.5483, 0.653, 3.3602, 0.6548, 3.3602, 0.81, 2.5478, 0.81] | word use for size Désignation
#   h4 | 13.786 pt | Salle de musique : CLYPSO KREATION pour mur de 71 à 98 mm (n | polygone [0.4769, 1.0029, 0.7773, 1.0033, 0.7769, 1.1465, 0.4765, 1.1461] | word use for size Salle
#   h3 | 14.362 pt | Salle de musique : Béquille B01 Inox PDDT Dont éco-contribut | polygone [0.4756, 2.8774, 0.7779, 2.8791, 0.7773, 3.027, 0.4752, 3.0264] | word use for size Salle
#   h3 | 14.458 pt | Dégagement 1 : Porte Plane Kreation - Ame pleine Haut 2040 m | polygone [0.4801, 4.3061, 1.2522, 4.31, 1.2518, 4.4562, 0.4797, 4.4567] | word use for size Dégagement
#   h2 | 14.938 pt | Dégagement 1 : CHASSIS ECLISSE 95 Châssis eclisse 95 UNIQUE  | polygone [0.482, 6.5714, 1.252, 6.5743, 1.2515, 6.7213, 0.4812, 6.727] | word use for size Dégagement
#   h2 | 14.870 pt | Dégagement 1 : GARNITURE SANS SERRURE GARNITURE CHROME SATIN | polygone [0.48, 7.3821, 1.2506, 7.3844, 1.2504, 7.5309, 0.4796, 7.537] | word use for size Dégagement
#   h2 | 15.043 pt | Désignation | polygone [2.5486, 0.6533, 3.3602, 0.6559, 3.3602, 0.81, 2.548, 0.81] | word use for size Désignation
#   h5 | 13.238 pt | Toilettes 2 : Porte Plane Kreation - Ame pleine | polygone [0.4723, 1.0034, 1.0104, 1.0027, 1.0102, 1.1406, 0.4721, 1.1402] | word use for size Toilettes
#   h5 | 12.893 pt | Haut 2040 mm x Larg 830 mm . Porte ferree pour Clypso Kreati | polygone [0.4769, 1.1521, 0.7801, 1.1529, 0.7799, 1.2864, 0.4767, 1.2859] | word use for size Haut
#   h4 | 13.978 pt | Toilettes 2 : CLYPSO KREATION pour mur de 71 à 98 mm (nº1) H | polygone [0.4746, 3.265, 1.0113, 3.2671, 1.0111, 3.4106, 0.4745, 3.4091] | word use for size Toilettes
#   h4 | 13.910 pt | Toilettes 2 : Béquille B01 Inox BCC Dont éco-contribution RE | polygone [0.4736, 5.1442, 1.0116, 5.1437, 1.0114, 5.2886, 0.4737, 5.2877] | word use for size Toilettes
#   h3 | 14.573 pt | Dressing : Porte Plane Kreation - Ame pleine Haut 2040 mm x  | polygone [0.4815, 6.5738, 0.9946, 6.5757, 0.9938, 6.7256, 0.4811, 6.7252] | word use for size Dressing
#   h2 | 15.139 pt | Désignation | polygone [2.548, 0.6523, 3.3602, 0.6549, 3.3602, 0.81, 2.5474, 0.81] | word use for size Désignation
#   h3 | 14.544 pt | Dressing : CLYPSO KREATION pour mur de 71 à 98 mm (nº1) Haut | polygone [0.4818, 1.0019, 0.9926, 1.0023, 0.9922, 1.1525, 0.4814, 1.1534] | word use for size Dressing
#   h5 | 11.549 pt | . Pour porte Pleinitude . Chants droits . Charnières invisib | polygone [1.8153, 1.3114, 1.8351, 1.3116, 1.835, 1.4316, 1.8152, 1.4317] | word use for size .
#   h3 | 14.582 pt | Dressing : Béquille B01 Inox PDDT | polygone [0.48, 2.8782, 1.0066, 2.8788, 1.0059, 3.0292, 0.4794, 3.0301] | word use for size Dressing
#   h5 | 12.547 pt | Dont éco-contribution REP PMCB : 0,01€ HT O
# finition INOX
# B0 | polygone [1.7376, 3.1617, 1.9714, 3.1603, 1.9705, 3.291, 1.7372, 3.2897] | word use for size Dont
#   h5 | 13.603 pt | Chambre 1 : Porte Plane Kreation - Ame pleine | polygone [0.4789, 4.3076, 1.0306, 4.3079, 1.0299, 4.4493, 0.4785, 4.4479] | word use for size Chambre
#   h5 | 13.536 pt | Haut 2040 mm x Larg 830 mm . Porte ferrée pour Clypso Kreati | polygone [0.4782, 4.4556, 0.7811, 4.456, 0.7806, 4.5966, 0.4779, 4.5946] | word use for size Haut
#   h4 | 13.930 pt | Chambre 1 : CLYPSO KREATION pour mur de 71 à 98 mm (nº1) Hau | polygone [0.4801, 6.571, 1.0301, 6.5733, 1.0295, 6.7161, 0.4794, 6.7137] | word use for size Chambre
#   h5 | 11.894 pt | . Pour porte Pleinitude | polygone [1.8143, 6.8798, 1.8349, 6.8799, 1.8347, 7.0037, 1.8141, 7.0037] | word use for size .
#   h5 | 11.328 pt | . Chants droits . Charnières invisibles . Gâche pour serrure | polygone [1.8162, 7.0087, 1.8352, 7.0094, 1.8353, 7.1266, 1.8163, 7.1267] | word use for size .
#   h4 | 13.987 pt | Chambre 1 : Béquille B01 Inox PDDT | polygone [0.4781, 8.447, 1.0308, 8.447, 1.03, 8.5927, 0.4775, 8.5915] | word use for size Chambre
#   h5 | 12.586 pt | Dont éco-contribution REP PMCB : 0,01€ HT O
# finition INOX
# B0 | polygone [1.7385, 8.7325, 1.9706, 8.7311, 1.9697, 8.8622, 1.7381, 8.861] | word use for size Dont
#   h1 | 15.379 pt | Désignation | polygone [2.5482, 0.652, 3.3602, 0.6549, 3.3602, 0.8122, 2.5476, 0.8107] | word use for size Désignation
#   h5 | 13.229 pt | Chambre 2 : Porte Plane Kreation - Ame pleine | polygone [0.4783, 1.0031, 1.0302, 1.0029, 1.0295, 1.1407, 0.4778, 1.1403] | word use for size Chambre
#   h5 | 13.094 pt | Haut 2040 mm x Larg 830 mm . Porte ferrée pour Clypso Kreati | polygone [0.4768, 1.1506, 0.7803, 1.1518, 0.78, 1.287, 0.4764, 1.2859] | word use for size Haut
#   h4 | 14.054 pt | Chambre 2 : CLYPSO KREATION pour mur de 71 à 98 mm (nº1) Hau | polygone [0.4798, 3.2641, 1.0297, 3.2666, 1.0293, 3.4105, 0.4794, 3.4085] | word use for size Chambre
#   h5 | 11.741 pt | . Pour porte Pleinitude . Chants droits . Charnières invisib | polygone [1.8162, 3.5779, 1.8362, 3.578, 1.8362, 3.7, 1.8161, 3.7002] | word use for size .
#   h4 | 14.160 pt | Chambre 2 : Béquille B01 Inox PDDT | polygone [0.4784, 5.1414, 1.0312, 5.1426, 1.0304, 5.2889, 0.478, 5.2871] | word use for size Chambre
#   h5 | 12.538 pt | Dont éco-contribution REP PMCB : 0,01€ HT O
# finition INOX
# B0 | polygone [1.7371, 5.426, 1.9709, 5.4247, 1.9703, 5.5553, 1.7368, 5.5548] | word use for size Dont
#   h4 | 13.910 pt | Salle d'eau 1 : Porte Plane Kreation - Ame pleine Haut 2040  | polygone [0.4749, 6.5713, 0.7754, 6.5736, 0.7747, 6.7162, 0.4745, 6.7137] | word use for size Salle
#   h5 | 12.307 pt | . Porte ferrée pour Clypso Kreation . 1 vantail . Chants dro | polygone [1.8143, 6.879, 1.8362, 6.8788, 1.8362, 7.0068, 1.8145, 7.007] | word use for size .
#   h1 | 15.418 pt | Désignation | polygone [2.5482, 0.6518, 3.3602, 0.6541, 3.3602, 0.8124, 2.5477, 0.8113] | word use for size Désignation
#   h5 | 13.642 pt | Salle d'eau 1 : CLYPSO KREATION pour mur de 71 à 98 mm (nº1) | polygone [0.4765, 1.0008, 0.7757, 1.0014, 0.7755, 1.1427, 0.4762, 1.1429] | word use for size Salle
#   h5 | 12.787 pt | Haut 2040 mm x Larg 830 mm . Pour porte Pleinitude . Chants  | polygone [0.4795, 1.153, 0.7799, 1.1534, 0.7799, 1.2862, 0.4795, 1.286] | word use for size Haut
#   h4 | 13.968 pt | Salle d'eau 1 : Béquille B01 Inox BCC | polygone [0.4759, 2.8765, 0.7735, 2.878, 0.7731, 3.022, 0.4756, 3.0214] | word use for size Salle
#   h5 | 12.461 pt | Dont éco-contribution REP PMCB : 0,01€ HT O
# finition INOX
# B0 | polygone [1.7381, 3.1624, 1.9704, 3.161, 1.9698, 3.2908, 1.7378, 3.2893] | word use for size Dont
#   h5 | 13.469 pt | Bureau : Porte Plane Kreation - Ame pleine | polygone [0.4812, 4.3108, 0.9062, 4.3104, 0.9058, 4.4507, 0.481, 4.4473] | word use for size Bureau
#   h5 | 13.334 pt | Haut 2040 mm x Larg 830 mm . Porte coulissante . 1 vantail . | polygone [0.4795, 4.4573, 0.7816, 4.4576, 0.7812, 4.5962, 0.4793, 4.5949] | word use for size Haut
#   h5 | 13.085 pt | Bureau : CHASSIS ECLISSE 95 Châssis eclisse 95 UNIQUE pour P | polygone [0.4821, 6.578, 0.9062, 6.5767, 0.9058, 6.711, 0.4817, 6.713] | word use for size Bureau
#   h5 | 12.922 pt | Bureau : GARNITURE SERRURE L GARNITURE CHROME SATINE AVEC SE | polygone [0.4803, 7.3913, 0.9143, 7.3885, 0.9142, 7.5201, 0.4802, 7.5231] | word use for size Bureau
#   h2 | 15.091 pt | Désignation | polygone [2.5485, 0.6528, 3.3602, 0.6554, 3.3596, 0.81, 2.548, 0.81] | word use for size Désignation
#   h5 | 13.238 pt | Toilettes 3 : Porte Plane Kreation - Ame pleine Haut 2040 mm | polygone [0.4724, 1.0032, 1.011, 1.0026, 1.0107, 1.1405, 0.4722, 1.1401] | word use for size Toilettes
#   h4 | 13.968 pt | Toilettes 3 : CLYPSO KREATION pour mur de 71 à 98 mm (nº1) H | polygone [0.4748, 3.265, 1.0105, 3.267, 1.0103, 3.4105, 0.4747, 3.4088] | word use for size Toilettes
#   h4 | 13.891 pt | Toilettes 3 : Béquille B01 Inox BCC Dont éco-contribution RE | polygone [0.4736, 5.144, 1.0104, 5.1437, 1.0101, 5.2884, 0.4738, 5.2873] | word use for size Toilettes
#   h4 | 13.814 pt | Salle d'eau 2 : Porte Plane Kreation - Ame pleine Haut 2040  | polygone [0.4752, 6.5719, 0.7757, 6.5744, 0.7753, 6.7158, 0.4749, 6.7133] | word use for size Salle
#   h1 | 15.485 pt | Désignation | polygone [2.548, 0.6517, 3.3602, 0.6535, 3.3602, 0.813, 2.5475, 0.8123] | word use for size Désignation
#   h5 | 13.690 pt | Salle d'eau 2 : CLYPSO KREATION pour mur de 71 à 98 mm (nº1) | polygone [0.4764, 1.0005, 0.7745, 1.0011, 0.7742, 1.1431, 0.4761, 1.1431] | word use for size Salle
#   h5 | 11.558 pt | . Pour porte Pleinitude . Chants droits . Charnières invisib | polygone [1.8157, 1.3112, 1.8355, 1.3115, 1.8354, 1.4315, 1.8156, 1.4316] | word use for size .
#   h4 | 14.093 pt | Salle d'eau 2 : Béquille B01 Inox BCC | polygone [0.476, 2.8758, 0.7736, 2.8773, 0.7732, 3.0226, 0.4756, 3.0223] | word use for size Salle
#   h5 | 12.614 pt | Dont éco-contribution REP PMCB : 0,01€ HT O
# finition INOX
# B0 | polygone [1.7379, 3.1614, 1.971, 3.1601, 1.9702, 3.2915, 1.7376, 3.2902] | word use for size Dont
#   h5 | 13.651 pt | Chambre 4 : Porte Plane Kreation - Ame pleine | polygone [0.4792, 4.3073, 1.0301, 4.3078, 1.0295, 4.4495, 0.4788, 4.4478] | word use for size Chambre
#   h5 | 13.488 pt | Haut 2040 mm x Larg 830 mm . Porte ferree pour Clypso Kreati | polygone [0.4784, 4.4562, 0.7811, 4.4562, 0.7807, 4.5967, 0.4782, 4.5951] | word use for size Haut
#   h4 | 13.891 pt | Chambre 4 : CLYPSO KREATION pour mur de 71 à 98 mm (nº1) Hau | polygone [0.4801, 6.5712, 1.0295, 6.5736, 1.0289, 6.7159, 0.4795, 6.7139] | word use for size Chambre
#   h5 | 11.894 pt | . Pour porte Pleinitude | polygone [1.8147, 6.8798, 1.8354, 6.8798, 1.8352, 7.0037, 1.8146, 7.0037] | word use for size .
#   h5 | 11.357 pt | . Chants droits . Charnières invisibles . Gâche pour serrure | polygone [1.8166, 7.0087, 1.8357, 7.0095, 1.8358, 7.127, 1.8168, 7.127] | word use for size .
#   h4 | 13.910 pt | Chambre 4 : Béquille B01 Inox PDDT | polygone [0.4782, 8.4473, 1.0294, 8.4474, 1.0287, 8.5922, 0.4777, 8.5914] | word use for size Chambre
#   h5 | 12.624 pt | Dont éco-contribution REP PMCB : 0,01€ HT O
# finition INOX
# B0 | polygone [1.7387, 8.7323, 1.9713, 8.731, 1.9706, 8.8625, 1.7382, 8.8614] | word use for size Dont
#   h1 | 15.360 pt | Désignation | polygone [2.5483, 0.6522, 3.3602, 0.6553, 3.3602, 0.8122, 2.5477, 0.8108] | word use for size Désignation
#   h5 | 13.238 pt | Chambre 3 : Porte Plane Kreation - Ame pleine Haut 2040 mm x | polygone [0.4784, 1.0029, 1.0292, 1.0028, 1.0286, 1.1407, 0.478, 1.1404] | word use for size Chambre
#   h4 | 13.939 pt | Chambre 3 : CLYPSO KREATION pour mur de 71 à 98 mm (nº1) Hau | polygone [0.4801, 3.2649, 1.0299, 3.2673, 1.0294, 3.4101, 0.4797, 3.4085] | word use for size Chambre
#   h5 | 11.702 pt | . Pour porte Pleinitude . Chants droits . Charnières invisib | polygone [1.8166, 3.5782, 1.8346, 3.5783, 1.8345, 3.6999, 1.8165, 3.7001] | word use for size .
#   h4 | 14.026 pt | Chambre 3 : Béquille B01 Inox PDDT Dont éco-contribution REP | polygone [0.4786, 5.1424, 1.0303, 5.1427, 1.0293, 5.2885, 0.4782, 5.2872] | word use for size Chambre
#   h5 | 11.789 pt | Pose CHASSIS CIRCULAIRE: HABILLAGES - FINITIONS (mis en plac | polygone [0.4816, 6.5842, 0.7867, 6.5865, 0.7867, 6.707, 0.481, 6.7058] | word use for size Pose
#   h3 | 14.285 pt | Pose des huisseries et des portes en fin de chantier avec po | polygone [0.479, 7.5126, 0.7704, 7.5135, 0.7698, 7.6614, 0.4784, 7.6589] | word use for size Pose
#   h5 | 13.200 pt | Compris: contrôle avant pose | polygone [1.7365, 7.9427, 2.1538, 7.9417, 2.1532, 8.0792, 1.7363, 8.0792] | word use for size Compris:
#   h1 | 15.331 pt | Désignation | polygone [2.5488, 0.6525, 3.3602, 0.6559, 3.3602, 0.8122, 2.5477, 0.8086] | word use for size Désignation
#   h5 | 0.000 pt |  | polygone None | word use for size None
#   h5 | 12.998 pt | Détail TVA | polygone [0.4589, 6.4615, 0.8135, 6.463, 0.8133, 6.596, 0.4588, 6.5969] | word use for size Détail
#   h5 | 12.538 pt | Base HT | polygone [0.4598, 6.7826, 0.7497, 6.7845, 0.7493, 6.9117, 0.4595, 6.9132] | word use for size Base
#   h5 | 12.547 pt | Montant TVA | polygone [0.4574, 7.0963, 0.972, 7.0984, 0.9718, 7.2263, 0.4576, 7.227] | word use for size Montant
#   h2 | 14.832 pt | Total HT : | polygone [5.5679, 6.4567, 5.8916, 6.46, 5.8914, 6.6105, 5.5679, 6.6112] | word use for size Total
#   h3 | 14.458 pt | Total TVA : | polygone [5.4924, 6.7677, 5.843, 6.7697, 5.8429, 6.917, 5.4924, 6.9183] | word use for size Total
#   h3 | 14.669 pt | Total TTC : | polygone [5.4377, 7.0875, 5.8121, 7.0879, 5.812, 7.2403, 5.4378, 7.2403] | word use for size Total
# --- fin debug ---
#
#
#
#
#
#
# ####################
#
#
#
#
#
#                          _ **Désignation**                                                                                                                                                                                                                                                                                                                                                                                                                                                                 |                               Qté |     Pu HT     |       Total HT   |        TVA
#     _ **Entrée : Porte circulaire . - Châssis unique version CIRCULAR plaque de plâtre rayon 1200 ouverture à droite pour porte de LP=830 HP=2040 mm - Porte + Habillage + Couvre-joints unique version CIRCULAR plaqué Tanganika rayon 1200 ouverture à droite pour porte de LP= 830 HP=2040 mm - Kiit AGB RONDO (serrure condamnation/decondamnation) finition Chromé Satiné pour porte coulissante bois (épr 40 mm) . SOUSRESERVE D'UN DESCRIPTIF TECHNIQUE PLUS PRECIS POUR ADAPTER AU BESOIN CLIENT** |                                1  |    3 829,44 € |       3 829,44 € |       20 %
#     _ **Cellier : Porte Plane Kreation - Ame pleine Haut 2040 mm x Larg 830 mm . Porte ferrée pour Clypso Kreation . 1 vantail . Chants droits . Coloris : M05 Chêne d'Orleans Taupe . Charnières invisibles . Joint en traverse basse : 1 lèvre non coupe feu . Serrure PD 1/2 tour magnétique axe à 50 mm . Gauche poussant . Avec emballage Dont éco-contribution REP PMCB : 1,18€ HT Fabrication française**                                                                                           |                                1  |   210,33 €    |      210,33 €    |       20 %
#     _ **Cellier : CLYPSO KREATION pour mur de 71 à 98 mm (nº1) Haut 2040 mm x Larg 830 mm . Pour porte Pleinitude . Chants droits . Charnières invisibles . Gâche pour serrure 1 pt magnétique . Coloris : M05 Chêne d'Orleans Taupe . Gauche poussant Dont éco-contribution REP PMCB : 0,17€ HT Fabrication française**                                                                                                                                                                                   |                                1  |   281,08 €    |      281,08 €    |       20 %
#
#                          _ **Désignation**                                                                                                                                                                                                                                                                                                              |                               Qté |     Pu HT  |       Total HT |        TVA
# ...
#     _ **Haut 2040 mm x Larg 830 mm . Pour porte Pleinitude . Chants droits . Charnières invisibles . Gâche pour serrure 1 pt magnétique . Coloris : M05 Chêne d'Orleans Taupe . Gauche poussant Dont éco-contribution REP PMCB : 0,17€ HT Fabrication française**                                                                                                                                                   |                                   |            |                |
#     _ **Salle d'eau 1 : Béquille B01 Inox BCC**                                                                                                                                                                                                                                                                                                                                                                     |                                1  |   68,58 €  |      68,58 €   |       20 %
#                  _ __**Dont éco-contribution REP PMCB : 0,01€ HT O
# finition INOX
# B01**__                                                                                                                                                                                                                                                                                                                            |                                   |            |                |
#     _ **Bureau : Porte Plane Kreation - Ame pleine**                                                                                                                                                                                                                                                                                                                                                                |                                1  |   469,22 € |      469,22 €  |       20 %
#     _ **Haut 2040 mm x Larg 830 mm . Porte coulissante . 1 vantail . Chants droits . Coloris : M05 Chêne d'Orleans Taupe . Habillage pour cloison 98mm : coloris Chêne d'Orleans Taupe M05 . Entaillage serrure pour porte coulissante, mortaise + cuvette + tire doigt . Sens d'ouverture à définir . Rainure en traverse basse . Avec emballage Dont éco-contribution REP PMCB : 1,35€ HT Fabrication française** |                                   |            |                |
#     _ **Bureau : CHASSIS ECLISSE 95 Châssis eclisse 95 UNIQUE pour Plaques de plâtre, Epaisseur cloison finie de 95 mm, version prémontée compris châssis métallique**                                                                                                                                                                                                                                              |                                1  |   399,50 € |      399,50 €  |       20 %
#     _ **Bureau : GARNITURE SERRURE L GARNITURE CHROME SATINE AVEC SERRURE BCC**                                                                                                                                                                                                                                                                                                                                     |                                1  |   50,34 €  |      50,34 €   |       20 %
#
#                          _ **Désignation**                                                                                                                                                                                                                                                                                                                                                                                            |                               Qté |     Pu HT  |       Total HT |        TVA
#     _ __**Toilettes 3 : Porte Plane Kreation - Ame pleine Haut 2040 mm x Larg 830 mm . Porte ferree pour Clypso Kreation . 1 vantail . Chants droits . Coloris : M05 Chêne d'Orleans Taupe . Charnières invisibles . Joint en traverse basse : 1 lèvre non coupe feu Serrure Bec de cane à condamnation magnétique axe à 50 mm . Droite poussant . Avec emballage Dont éco-contribution REP PMCB : 1,18€ HT Fabrication française**__ |                                1  |   210,33 € |      210,33 €  |       20 %
#     _ **Toilettes 3 : CLYPSO KREATION pour mur de 71 à 98 mm (nº1) Haut 2040 mm x Larg 830 mm . Pour porte Pleinitude . Chants droits . Charnières invisibles . Gâche pour serrure 1 pt magnétique . Coloris : M05 Chêne d'Orleans Taupe . Droite poussant Dont éco-contribution REP PMCB : 0,17€ HT Fabrication française**                                                                                                          |                                1  |   281,08 € |      281,08 €  |       20 %
#     _ **Toilettes 3 : Béquille B01 Inox BCC Dont éco-contribution REP PMCB : 0,01€ HT O B01 finition INOX**                                                                                                                                                                                                                                                                                                                           |                                1  |   68,58 €  |      68,58 €   |       20 %
#     _ **Salle d'eau 2 : Porte Plane Kreation - Ame pleine Haut 2040 mm x Larg 830 mm . Porte ferrée pour Clypso Kreation . 1 vantail . Chants droits . Coloris : M05 Chêne d'Orleans Taupe . Charnières invisibles . Joint en traverse basse : 1 lèvre non coupe feu . Serrure Bec de cane à condamnation magnétique axe à 50 mm . Droite poussant . Avec emballage Dont éco-contribution REP PMCB : 1,18€ HT Fabrication française** |                                1  |   210,33 € |      210,33 €  |       20 %
#
#                          _ **Désignation**                                                                                                                                                                                                                                                                                                                           |                               Qté |     Pu HT  |       Total HT |       TVA
#     _ __**Salle d'eau 2 : CLYPSO KREATION pour mur de 71 à 98 mm (nº1) Haut 2040 mm x Larg 830 mm**__                                                                                                                                                                                                                                                                |                                1  |   281,08 € |      281,08 €  |       20 %
#                   _ . Pour porte Pleinitude . Chants droits . Charnières invisibles . Gâche pour serrure 1 pt magnétique . Coloris : M05 Chêne d'Orleans Taupe . Droite poussant Dont éco-contribution REP PMCB : 0,17€ HT Fabrication française                                                                                                                     |                                   |            |                |
#     _ **Salle d'eau 2 : Béquille B01 Inox BCC**                                                                                                                                                                                                                                                                                                                      |                                1  |   68,58 €  |      68,58 €   |       20 %
#                  _ **Dont éco-contribution REP PMCB : 0,01€ HT O
# finition INOX
# B01**                                                                                                                                                                                                                                                                                 |                                   |            |                |
#     _ **Chambre 4 : Porte Plane Kreation - Ame pleine**                                                                                                                                                                                                                                                                                                              |                                1  |   210,33 € |      210,33 €  |       20 %
#     _ **Haut 2040 mm x Larg 830 mm . Porte ferree pour Clypso Kreation . 1 vantail . Chants droits . Coloris : M05 Chêne d'Orleans Taupe . Charnières invisibles . Joint en traverse basse : 1 lèvre non coupe feu . Serrure PD 1/2 tour magnétique axe à 50 mm . Gauche poussant . Avec emballage Dont éco-contribution REP PMCB : 1,18€ HT Fabrication française** |                                   |            |                |
#     _ **Chambre 4 : CLYPSO KREATION pour mur de 71 à 98 mm (nº1) Haut 2040 mm x Larg 830 mm**                                                                                                                                                                                                                                                                        |                                1  |   281,08 € |      281,08 €  |       20 %
#                   _ . Pour porte Pleinitude                                                                                                                                                                                                                                                                                                                          |                                   |            |                |
#                   _ . Chants droits . Charnières invisibles . Gâche pour serrure 1 pt magnétique . Coloris : M05 Chêne d'Orleans Taupe . Gauche poussant Dont éco-contribution REP PMCB : 0,17€ HT Fabrication française                                                                                                                                             |                                   |            |                |
#     _ **Chambre 4 : Béquille B01 Inox PDDT**                                                                                                                                                                                                                                                                                                                         |                                1  |   47,88 €  |      47,88 €   |       20 %
#                  _ **Dont éco-contribution REP PMCB : 0,01€ HT O
# finition INOX
# B01**                                                                                                                                                                                                                                                                                 |                                   |            |                |
#
#                          _ **Désignation**                                                                                                                                                                                                                                                                                                                                                                           |                               Qté |     Pu HT     |       Total HT   |       TVA
#     _ __**Chambre 3 : Porte Plane Kreation - Ame pleine Haut 2040 mm x Larg 830 mm . Porte ferrée pour Clypso Kreation . 1 vantail . Chants droits . Coloris : M05 Chêne d'Orleans Taupe . Charnières invisibles . Joint en traverse basse : 1 lèvre non coupe feu Serrure PD 1/2 tour magnétique axe à 50 mm . Droite poussant . Avec emballage Dont éco-contribution REP PMCB : 1,18€ HT Fabrication française**__ |                                1  |   210,33 €    |      210,33 €    |       20 %
#     _ **Chambre 3 : CLYPSO KREATION pour mur de 71 à 98 mm (nº1) Haut 2040 mm x Larg 830 mm**                                                                                                                                                                                                                                                                                                                        |                                1  |   281,08 €    |      281,08 €    |       20 %
#                   _ . Pour porte Pleinitude . Chants droits . Charnières invisibles . Gâche pour serrure 1 pt magnétique . Coloris : M05 Chêne d'Orleans Taupe . Droite poussant Dont éco-contribution REP PMCB : 0,17€ HT Fabrication française                                                                                                                                                                     |                                   |               |                  |
#     _ **Chambre 3 : Béquille B01 Inox PDDT Dont éco-contribution REP PMCB : 0,01€ HT O
# finition INOX
# B01**                                                                                                                                                                                                                                                                                                           |                                1  |   47,88 €     |      47,88 €     |       20 %
#     _ **Pose CHASSIS CIRCULAIRE: HABILLAGES - FINITIONS (mis en place par le plaquiste)**                                                                                                                                                                                                                                                                                                                            |                                1  |   343,88 €    |      343,88 €    |       20 %
#     _ **Pose des huisseries et des portes en fin de chantier avec pose des poignées et réglage**                                                                                                                                                                                                                                                                                                                     |                                1  |    2 200,80 € |       2 200,80 € |       20 %
#                  _ Compris: contrôle avant pose                                                                                                                                                                                                                                                                                                                                                                      |                                   |               |                  |
#
#                          _ **Désignation** |                               Qté |      Pu HT |       Total HT |        TVA
#                                            |                                   |            |                |
#
#     _ **Détail TVA**  |               20 %        |          10 % |          5,5 %
#     _ **Base HT**     |              14 743, 18 € |       0,00 €  |       0,00 €
#     _ **Montant TVA** |               2 948,64 €  |       0,00 €  |       0,00 €
#
#                                                        _ Total HT :         |               14 743,18 €
#                                                       _ Total TVA :         |                2 948,64 €
#                                                       _ __**Total TTC :**__ |              17 691,82 €
#
#
# ✅ Proposal text written to /Users/remillieux/Documents/Kleek/OCR/data/proposal_html/DEVIS LOIRE MENUISERIES SERVICES (L_M_S_)_GUERIN - TESSIER - charnieres invisbles.html

# %%
from openai import OpenAI

from pydantic import BaseModel, Field


class NoeudStructureProduitsDevis(BaseModel):
    """
    Représente la structure des produits du devis.
    """

    nom: str = Field(
        ...,
        description="Nom du noeud de la structure des produits du devis",
    )

    sous_groupes_produits: Optional[List["NoeudStructureProduitsDevis"]] = Field(
        None,
        description="Liste des sous-groupes des produits du devis",
    )


class StructureProduitsDevis(BaseModel):
    groupes_produits: Optional[List["NoeudStructureProduitsDevis"]] = Field(
        None,
        description="Une ou plusieurs groupes de produits du devis. Si il n'y a qu'un seul groupe, la liste est vide.",
    )


PROPOSAL_SECTION_ANALYZER_SYSTEM_PROMPT = """Vous êtes le meilleur analyseur de devis du monde. Vous devez analyser un devis au format HTML pour déterminer la structure des catégories de produits de celui-ci, c'est-à-dire les différentes sections et sous-sections des produits du devis. Vous devez vérifier que le prix total de la catégorie correspond bien au prix des produits listés dans la catégorie. Respectez la structure originale du devis, ne tentez pas de fusionner des lignes. Ne comptez pas les nouvelles pages comme une nouvelle section. N'inventez aucune ligne."""

model = "gpt-4.1"

client = OpenAI()

file = client.files.create(
    file=open(proposal_path.proposal_path, "rb"), purpose="user_data"
)

with open(
    proposal_path.proposal_html_path,
    "r",
    encoding="utf-8",
) as f:
    ocr_output = f.read()

completion = client.beta.chat.completions.parse(
    model=model,
    messages=[
        {
            "role": "system",
            "content": [
                {"type": "text", "text": PROPOSAL_SECTION_ANALYZER_SYSTEM_PROMPT}
            ],
        },
        {
            "role": "user",
            "content": [
                {"type": "text", "text": "Voici le devis:\n\n" + ocr_output},
                {
                    "type": "file",
                    "file": {
                        "file_id": file.id,
                    },
                },
            ],
        },
    ],
    tools=[],
    store=False,
    response_format=StructureProduitsDevis,
    # reasoning_effort="low",
)

proposal_structure: Optional[StructureProduitsDevis] = completion.choices[
    0
].message.parsed

if proposal_structure is None:
    logger.error("PROPOSAL => No structured proposal found.")


proposal_structure_json = proposal_structure.model_dump_json(indent=2)

print(f"Section analysis :\n{proposal_structure_json}")

print(f"Section analysis token :{token_counter(proposal_structure_json)}")

a_out = Path(proposal_path.proposal_section_analysis_path)

a_out.parent.mkdir(parents=True, exist_ok=True)

a_out.write_text(proposal_structure_json, encoding="utf-8")

print(f"✅ Section analysis written to {a_out.resolve()}")

cost_tracker.add_openai_query(
    model=model,
    nb_input_token=completion.usage.prompt_tokens,
    nb_output_token=completion.usage.completion_tokens,
    function_name="proposal_section_analyzer",
)

print(f"Total cost: {cost_tracker.cost.model_dump_json(indent=2)}")
# Out:
# Section analysis :
# {
#   "groupes_produits": [
#     {
#       "nom": "Entrée",
#       "sous_groupes_produits": [
#         {
#           "nom": "Porte circulaire",
#           "sous_groupes_produits": null
#         }
#       ]
#     },
#     {
#       "nom": "Cellier",
#       "sous_groupes_produits": [
#         {
#           "nom": "Porte Plane Kreation - Ame pleine",
#           "sous_groupes_produits": null
#         },
#         {
#           "nom": "CLYPSO KREATION pour mur de 71 à 98 mm (n°1)",
#           "sous_groupes_produits": null
#         },
#         {
#           "nom": "Béquille B01 Inox PDDT",
#           "sous_groupes_produits": null
#         }
#       ]
#     },
#     {
#       "nom": "Dégagement 2",
#       "sous_groupes_produits": [
#         {
#           "nom": "Porte Plane Kreation - Ame pleine",
#           "sous_groupes_produits": null
#         },
#         {
#           "nom": "CLYPSO KREATION pour mur de 71 à 98 mm (n°1)",
#           "sous_groupes_produits": null
#         },
#         {
#           "nom": "Béquille B01 Inox PDDT",
#           "sous_groupes_produits": null
#         }
#       ]
#     },
#     {
#       "nom": "Salle de musique",
#       "sous_groupes_produits": [
#         {
#           "nom": "Porte Plane Kreation - Ame pleine",
#           "sous_groupes_produits": null
#         },
#         {
#           "nom": "CLYPSO KREATION pour mur de 71 à 98 mm (n°1)",
#           "sous_groupes_produits": null
#         },
#         {
#           "nom": "Béquille B01 Inox PDDT",
#           "sous_groupes_produits": null
#         }
#       ]
#     },
#     {
#       "nom": "Dégagement 1",
#       "sous_groupes_produits": [
#         {
#           "nom": "Porte Plane Kreation - Ame pleine",
#           "sous_groupes_produits": null
#         },
#         {
#           "nom": "CHASSIS ECLISSE 95",
#           "sous_groupes_produits": null
#         },
#         {
#           "nom": "GARNITURE SANS SERRURE",
#           "sous_groupes_produits": null
#         }
#       ]
#     },
#     {
#       "nom": "Toilettes 2",
#       "sous_groupes_produits": [
#         {
#           "nom": "Porte Plane Kreation - Ame pleine",
#           "sous_groupes_produits": null
#         },
#         {
#           "nom": "CLYPSO KREATION pour mur de 71 à 98 mm (n°1)",
#           "sous_groupes_produits": null
#         },
#         {
#           "nom": "Béquille B01 Inox BCC",
#           "sous_groupes_produits": null
#         }
#       ]
#     },
#     {
#       "nom": "Dressing",
#       "sous_groupes_produits": [
#         {
#           "nom": "Porte Plane Kreation - Ame pleine",
#           "sous_groupes_produits": null
#         },
#         {
#           "nom": "CLYPSO KREATION pour mur de 71 à 98 mm (n°1)",
#           "sous_groupes_produits": null
#         },
#         {
#           "nom": "Béquille B01 Inox PDDT",
#           "sous_groupes_produits": null
#         }
#       ]
#     },
#     {
#       "nom": "Chambre 1",
#       "sous_groupes_produits": [
#         {
#           "nom": "Porte Plane Kreation - Ame pleine",
#           "sous_groupes_produits": null
#         },
#         {
#           "nom": "CLYPSO KREATION pour mur de 71 à 98 mm (n°1)",
#           "sous_groupes_produits": null
#         },
#         {
#           "nom": "Béquille B01 Inox PDDT",
#           "sous_groupes_produits": null
#         }
#       ]
#     },
#     {
#       "nom": "Chambre 2",
#       "sous_groupes_produits": [
#         {
#           "nom": "Porte Plane Kreation - Ame pleine",
#           "sous_groupes_produits": null
#         },
#         {
#           "nom": "CLYPSO KREATION pour mur de 71 à 98 mm (n°1)",
#           "sous_groupes_produits": null
#         },
#         {
#           "nom": "Béquille B01 Inox PDDT",
#           "sous_groupes_produits": null
#         }
#       ]
#     },
#     {
#       "nom": "Salle d'eau 1",
#       "sous_groupes_produits": [
#         {
#           "nom": "Porte Plane Kreation - Ame pleine",
#           "sous_groupes_produits": null
#         },
#         {
#           "nom": "CLYPSO KREATION pour mur de 71 à 98 mm (n°1)",
#           "sous_groupes_produits": null
#         },
#         {
#           "nom": "Béquille B01 Inox BCC",
#           "sous_groupes_produits": null
#         }
#       ]
#     },
#     {
#       "nom": "Bureau",
#       "sous_groupes_produits": [
#         {
#           "nom": "Porte Plane Kreation - Ame pleine",
#           "sous_groupes_produits": null
#         },
#         {
#           "nom": "CHASSIS ECLISSE 95",
#           "sous_groupes_produits": null
#         },
#         {
#           "nom": "GARNITURE SERRURE L",
#           "sous_groupes_produits": null
#         }
#       ]
#     },
#     {
#       "nom": "Toilettes 3",
#       "sous_groupes_produits": [
#         {
#           "nom": "Porte Plane Kreation - Ame pleine",
#           "sous_groupes_produits": null
#         },
#         {
#           "nom": "CLYPSO KREATION pour mur de 71 à 98 mm (n°1)",
#           "sous_groupes_produits": null
#         },
#         {
#           "nom": "Béquille B01 Inox BCC",
#           "sous_groupes_produits": null
#         }
#       ]
#     },
#     {
#       "nom": "Salle d'eau 2",
#       "sous_groupes_produits": [
#         {
#           "nom": "Porte Plane Kreation - Ame pleine",
#           "sous_groupes_produits": null
#         },
#         {
#           "nom": "CLYPSO KREATION pour mur de 71 à 98 mm (n°1)",
#           "sous_groupes_produits": null
#         },
#         {
#           "nom": "Béquille B01 Inox BCC",
#           "sous_groupes_produits": null
#         }
#       ]
#     },
#     {
#       "nom": "Chambre 4",
#       "sous_groupes_produits": [
#         {
#           "nom": "Porte Plane Kreation - Ame pleine",
#           "sous_groupes_produits": null
#         },
#         {
#           "nom": "CLYPSO KREATION pour mur de 71 à 98 mm (n°1)",
#           "sous_groupes_produits": null
#         },
#         {
#           "nom": "Béquille B01 Inox PDDT",
#           "sous_groupes_produits": null
#         }
#       ]
#     },
#     {
#       "nom": "Chambre 3",
#       "sous_groupes_produits": [
#         {
#           "nom": "Porte Plane Kreation - Ame pleine",
#           "sous_groupes_produits": null
#         },
#         {
#           "nom": "CLYPSO KREATION pour mur de 71 à 98 mm (n°1)",
#           "sous_groupes_produits": null
#         },
#         {
#           "nom": "Béquille B01 Inox PDDT",
#           "sous_groupes_produits": null
#         }
#       ]
#     },
#     {
#       "nom": "Pose",
#       "sous_groupes_produits": [
#         {
#           "nom": "CHASSIS CIRCULAIRE: HABILLAGES - FINITIONS (mis en place par le plaquiste)",
#           "sous_groupes_produits": null
#         },
#         {
#           "nom": "Pose des huisseries et des portes en fin de chantier avec pose des poignées et réglage",
#           "sous_groupes_produits": null
#         }
#       ]
#     }
#   ]
# }
# Section analysis token :2027
# ✅ Section analysis written to /Users/remillieux/Documents/Kleek/OCR/data/proposal_section_analysis/DEVIS LOIRE MENUISERIES SERVICES (L_M_S_)_GUERIN - TESSIER - charnieres invisbles.json
# Total cost: {
#   "cost": 0.053212,
#   "cost_openai": {
#     "cost_openai_input": 0.041772,
#     "cost_openai_output": 0.01144,
#     "cost_embeddings": 0.0,
#     "cost_openai_total": 0.053212,
#     "nb_query": 1,
#     "queries": [
#       {
#         "model": "gpt-4.1",
#         "cost": 0.053212,
#         "function_name": "proposal_section_analyzer"
#       }
#     ]
#   }
# }

# %%
from app.agent.agent import Agent

PROPOSAL_ANALYZER_SYSTEM_PROMPT = (
    "Vous êtes le meilleur analyseur de devis du monde. Vous devez reconstruire le devis à partir d'un texte brut. "
    "Pour chaque produit du devis, vous devez très précisément noter son label, sa description, le lot auquel il appartient, son prix HT unitaire, la quantité, l'unité, la TVA et les possibles coûts supplémentaires. "
    "Les produits peuvent être groupés par catégories et ou contenir des sous-catégories de produits imbriquées. "
    "1 - Trouvez la structure exacte de chaque catégorie du devis. "
    "2 - Vérifiez que le prix total de la catégorie correspond bien au prix des produits listés dans la catégorie."
    "3 - Respectez la structure originale du devis, ne tentez pas de fusionner des lignes. "
    "4 - Ne comptez pas les nouvelles pages comme une nouvelle section. "
    "5 - N'inventez aucune ligne. "
)

model = "gpt-4.1"  # "gpt-4o-mini" or "o4-mini" or "gpt-4o" or "gpt-4o-2024-08-06"


class ProposalAnalyzer:
    """Proposal analyzer"""

    def __init__(self, cost_tracker: CostTracker) -> None:
        self.agent: Agent = Agent(
            api_key=env_param.OPENAI_API_KEY,
            model_name=model,
            system_promt=PROPOSAL_ANALYZER_SYSTEM_PROMPT,
            nb_retry=2,
            temprature=1 if model in ["o4-mini", "o3"] else 0,
            timeout=200,
            name="proposal_analyzer",
            cost_tracker=cost_tracker,
            reasoning_effort="high",
        )

    async def analyze(self, chat_historic: List[BaseMessage]) -> Optional[Devis]:
        """Structure the proposal"""

        proposal_structured: Optional[Devis] = await self.agent.run(
            response_format=Devis, chat_historic=chat_historic
        )

        return proposal_structured

    async def structure_proposal(
        self, raw_proposal: str, section_analysis: str
    ) -> Optional[Devis]:
        """Check if the client is spam"""

        chat_historic = [
            SystemMessage(content=PROPOSAL_ANALYZER_SYSTEM_PROMPT),
            HumanMessage(
                "Voici un premier analyse de la sturcutre du devis :\n\n"
                + section_analysis
            ),
            HumanMessage(content=raw_proposal),
        ]

        proposal_structured: Optional[Devis] = await self.analyze(chat_historic)

        if proposal_structured is None:
            logger.info("PROPOSAL => No structured proposal found.")

            return None

        return proposal_structured

# %%
with open(
    proposal_path.proposal_html_path,
    "r",
    encoding="utf-8",
) as f:
    raw_proposal = f.read()

with open(
    proposal_path.proposal_section_analysis_path,
    "r",
    encoding="utf-8",
) as f:
    section_analysis_raw = f.read()

section_analysis: Optional[StructureProduitsDevis] = (
    StructureProduitsDevis.model_validate_json(section_analysis_raw)
)

quote_analyzer = ProposalAnalyzer(cost_tracker=cost_tracker)

proposal: Optional[Devis] = await quote_analyzer.structure_proposal(
    raw_proposal=raw_proposal,
    section_analysis=section_analysis.model_dump_json(indent=2),
)

if proposal is None:
    logger.error("PROPOSAL => No structured proposal found.")
    exit(1)

proposal_json = proposal.model_dump_json(indent=2)

print(f"PROPOSAL => {proposal_json}")

a_out = Path(proposal_path.proposal_object_predicted_path)

a_out.parent.mkdir(parents=True, exist_ok=True)

a_out.write_text(proposal_json)

print(f"✅ OBJECT prédit écrit dans {a_out.resolve()}")


print(f"Total cost: {cost_tracker.cost.model_dump_json(indent=2)}")
# Out:
# 2025-06-27 19:41:53 INFO -> [app/performances/time_counter.py.time_counter.async_wrapper.37]:                                        PERFORMANCES => Function 'run' executed in : 51.529 seconds
# PROPOSAL => {
#   "devis_total_ht": 14743.18,
#   "devis_total_ttc": 17691.82,
#   "devis_total_tva": 2948.64,
#   "devis_coup_additionnel": null,
#   "devis_produits": [
#     {
#       "label": "Entrée : Porte circulaire",
#       "description": "Châssis unique version CIRCULAR plaque de plâtre rayon 1200 ouverture à droite pour porte de LP=830 HP=2040 mm - Porte + Habillage + Couvre-joints unique version CIRCULAR plaqué Tanganika rayon 1200 ouverture à droite pour porte de LP= 830 HP=2040 mm - Kit AGB RONDO (serrure condamnation/décondamnation) finition Chromé Satiné pour porte coulissante bois (ép. 40 mm). SOUS RESERVE D'UN DESCRIPTIF TECHNIQUE PLUS PRECIS POUR ADAPTER AU BESOIN CLIENT",
#       "quantite": 1.0,
#       "unitee_quantite": null,
#       "price_unitaire_ht": 3829.44,
#       "tva": "TVA 20%",
#       "cout_additionnel": null,
#       "sous_produits": null,
#       "lot": "MENUISERIE"
#     },
#     {
#       "label": "Cellier : Porte Plane Kreation - Ame pleine",
#       "description": "Haut 2040 mm x Larg 830 mm. Porte ferrée pour Clypso Kreation. 1 vantail. Chants droits. Coloris : M05 Chêne d'Orleans Taupe. Charnières invisibles. Joint en traverse basse : 1 lèvre non coupe feu. Serrure PD 1/2 tour magnétique axe à 50 mm. Gauche poussant. Avec emballage. Dont éco-contribution REP PMCB : 1,18€ HT. Fabrication française",
#       "quantite": 1.0,
#       "unitee_quantite": null,
#       "price_unitaire_ht": 210.33,
#       "tva": "TVA 20%",
#       "cout_additionnel": 1.18,
#       "sous_produits": null,
#       "lot": "MENUISERIE"
#     },
#     {
#       "label": "Cellier : CLYPSO KREATION pour mur de 71 à 98 mm (n°1)",
#       "description": "Haut 2040 mm x Larg 830 mm. Pour porte Pleinitude. Chants droits. Charnières invisibles. Gâche pour serrure 1 pt magnétique. Coloris : M05 Chêne d'Orleans Taupe. Gauche poussant. Dont éco-contribution REP PMCB : 0,17€ HT. Fabrication française",
#       "quantite": 1.0,
#       "unitee_quantite": null,
#       "price_unitaire_ht": 281.08,
#       "tva": "TVA 20%",
#       "cout_additionnel": 0.17,
#       "sous_produits": null,
#       "lot": "MENUISERIE"
#     },
#     {
#       "label": "Cellier : Béquille B01 Inox PDDT",
#       "description": "Béquille B01 Inox PDDT. Dont éco-contribution REP PMCB : 0,01€ HT. Finition INOX B01",
#       "quantite": 1.0,
#       "unitee_quantite": null,
#       "price_unitaire_ht": 47.88,
#       "tva": "TVA 20%",
#       "cout_additionnel": 0.01,
#       "sous_produits": null,
#       "lot": "MENUISERIE"
#     },
#     {
#       "label": "Dégagement 2 : Porte Plane Kreation - Ame pleine",
#       "description": "Haut 2040 mm x Larg 830 mm. Porte ferrée pour Clypso Kreation. 1 vantail. Chants droits. Coloris : M05 Chêne d'Orleans Taupe. Charnières invisibles. Joint en traverse basse : 1 lèvre non coupe feu. Serrure PD 1/2 tour magnétique axe à 50 mm. Droite poussant. Avec emballage. Dont éco-contribution REP PMCB : 1,18€ HT. Fabrication française",
#       "quantite": 1.0,
#       "unitee_quantite": null,
#       "price_unitaire_ht": 210.33,
#       "tva": "TVA 20%",
#       "cout_additionnel": 1.18,
#       "sous_produits": null,
#       "lot": "MENUISERIE"
#     },
#     {
#       "label": "Dégagement 2 : CLYPSO KREATION pour mur de 71 à 98 mm (n°1)",
#       "description": "Haut 2040 mm x Larg 830 mm. Pour porte Pleinitude. Chants droits. Charnières invisibles. Gâche pour serrure 1 pt magnétique. Coloris : M05 Chêne d'Orleans Taupe. Droite poussant. Dont éco-contribution REP PMCB : 0,17€ HT. Fabrication française",
#       "quantite": 1.0,
#       "unitee_quantite": null,
#       "price_unitaire_ht": 281.08,
#       "tva": "TVA 20%",
#       "cout_additionnel": 0.17,
#       "sous_produits": null,
#       "lot": "MENUISERIE"
#     },
#     {
#       "label": "Dégagement 2 : Béquille B01 Inox PDDT",
#       "description": "Béquille B01 Inox PDDT. Dont éco-contribution REP PMCB : 0,01€ HT. Finition INOX B01",
#       "quantite": 1.0,
#       "unitee_quantite": null,
#       "price_unitaire_ht": 47.88,
#       "tva": "TVA 20%",
#       "cout_additionnel": 0.01,
#       "sous_produits": null,
#       "lot": "MENUISERIE"
#     },
#     {
#       "label": "Salle de musique : Porte Plane Kreation - Ame pleine",
#       "description": "Haut 2040 mm x Larg 830 mm. Porte ferrée pour Clypso Kreation. 1 vantail. Chants droits. Coloris : M05 Chêne d'Orleans Taupe. Charnières invisibles. Joint en traverse basse : 1 lèvre non coupe feu. Serrure PD 1/2 tour magnétique axe à 50 mm. Gauche poussant. Avec emballage. Dont éco-contribution REP PMCB : 1,18€ HT. Fabrication française",
#       "quantite": 1.0,
#       "unitee_quantite": null,
#       "price_unitaire_ht": 210.33,
#       "tva": "TVA 20%",
#       "cout_additionnel": 1.18,
#       "sous_produits": null,
#       "lot": "MENUISERIE"
#     },
#     {
#       "label": "Salle de musique : CLYPSO KREATION pour mur de 71 à 98 mm (n°1)",
#       "description": "Haut 2040 mm x Larg 830 mm. Pour porte Pleinitude. Chants droits. Charnières invisibles. Gâche pour serrure 1 pt magnétique. Coloris : M05 Chêne d'Orleans Taupe. Gauche poussant. Dont éco-contribution REP PMCB : 0,17€ HT. Fabrication française",
#       "quantite": 1.0,
#       "unitee_quantite": null,
#       "price_unitaire_ht": 281.08,
#       "tva": "TVA 20%",
#       "cout_additionnel": 0.17,
#       "sous_produits": null,
#       "lot": "MENUISERIE"
#     },
#     {
#       "label": "Salle de musique : Béquille B01 Inox PDDT",
#       "description": "Béquille B01 Inox PDDT. Dont éco-contribution REP PMCB : 0,01€ HT. Finition INOX B01",
#       "quantite": 1.0,
#       "unitee_quantite": null,
#       "price_unitaire_ht": 47.88,
#       "tva": "TVA 20%",
#       "cout_additionnel": 0.01,
#       "sous_produits": null,
#       "lot": "MENUISERIE"
#     },
#     {
#       "label": "Dégagement 1 : Porte Plane Kreation - Ame pleine",
#       "description": "Haut 2040 mm x Larg 830 mm. Porte coulissante. 1 vantail. Chants droits. Coloris : M05 Chêne d'Orleans Taupe. Habillage pour cloison 98mm : coloris Chêne d'Orleans Taupe M05. Entaillage serrure pour porte coulissante, cuvette + tire doigt. Sens d'ouverture à définir. Rainure en traverse basse. Avec emballage. Dont éco-contribution REP PMCB : 1,35€ HT. Fabrication française",
#       "quantite": 1.0,
#       "unitee_quantite": null,
#       "price_unitaire_ht": 469.22,
#       "tva": "TVA 20%",
#       "cout_additionnel": 1.35,
#       "sous_produits": null,
#       "lot": "MENUISERIE"
#     },
#     {
#       "label": "Dégagement 1 : CHASSIS ECLISSE 95",
#       "description": "Châssis eclisse 95 UNIQUE pour Plaques de plâtre, Epaisseur cloison finie de 95 mm, version prémontée compris châssis métallique",
#       "quantite": 1.0,
#       "unitee_quantite": null,
#       "price_unitaire_ht": 399.5,
#       "tva": "TVA 20%",
#       "cout_additionnel": null,
#       "sous_produits": null,
#       "lot": "MENUISERIE"
#     },
#     {
#       "label": "Dégagement 1 : GARNITURE SANS SERRURE",
#       "description": "GARNITURE CHROME SATINE SANS SERRURE SANS PLAQUE TETIERE",
#       "quantite": 1.0,
#       "unitee_quantite": null,
#       "price_unitaire_ht": 27.0,
#       "tva": "TVA 20%",
#       "cout_additionnel": null,
#       "sous_produits": null,
#       "lot": "MENUISERIE"
#     },
#     {
#       "label": "Toilettes 2 : Porte Plane Kreation - Ame pleine",
#       "description": "Haut 2040 mm x Larg 830 mm. Porte ferrée pour Clypso Kreation. 1 vantail. Chants droits. Coloris : M05 Chêne d'Orleans Taupe. Charnières invisibles. Joint en traverse basse : 1 lèvre non coupe feu. Serrure Bec de cane à condamnation magnétique axe à 50 mm. Droite poussant. Avec emballage. Dont éco-contribution REP PMCB : 1,18€ HT. Fabrication française",
#       "quantite": 1.0,
#       "unitee_quantite": null,
#       "price_unitaire_ht": 210.33,
#       "tva": "TVA 20%",
#       "cout_additionnel": 1.18,
#       "sous_produits": null,
#       "lot": "MENUISERIE"
#     },
#     {
#       "label": "Toilettes 2 : CLYPSO KREATION pour mur de 71 à 98 mm (n°1)",
#       "description": "Haut 2040 mm x Larg 830 mm. Pour porte Pleinitude. Chants droits. Charnières invisibles. Gâche pour serrure 1 pt magnétique. Coloris : M05 Chêne d'Orleans Taupe. Droite poussant. Dont éco-contribution REP PMCB : 0,17€ HT. Fabrication française",
#       "quantite": 1.0,
#       "unitee_quantite": null,
#       "price_unitaire_ht": 281.08,
#       "tva": "TVA 20%",
#       "cout_additionnel": 0.17,
#       "sous_produits": null,
#       "lot": "MENUISERIE"
#     },
#     {
#       "label": "Toilettes 2 : Béquille B01 Inox BCC",
#       "description": "Béquille B01 Inox BCC. Dont éco-contribution REP PMCB : 0,01€ HT. Finition INOX B01",
#       "quantite": 1.0,
#       "unitee_quantite": null,
#       "price_unitaire_ht": 68.58,
#       "tva": "TVA 20%",
#       "cout_additionnel": 0.01,
#       "sous_produits": null,
#       "lot": "MENUISERIE"
#     },
#     {
#       "label": "Dressing : Porte Plane Kreation - Ame pleine",
#       "description": "Haut 2040 mm x Larg 830 mm. Porte ferrée pour Clypso Kreation. 1 vantail. Chants droits. Coloris : M05 Chêne d'Orleans Taupe. Charnières invisibles. Joint en traverse basse : 1 lèvre non coupe feu. Serrure PD 1/2 tour magnétique axe à 50 mm. Gauche poussant. Avec emballage. Dont éco-contribution REP PMCB : 1,18€ HT. Fabrication française",
#       "quantite": 1.0,
#       "unitee_quantite": null,
#       "price_unitaire_ht": 210.33,
#       "tva": "TVA 20%",
#       "cout_additionnel": 1.18,
#       "sous_produits": null,
#       "lot": "MENUISERIE"
#     },
#     {
#       "label": "Dressing : CLYPSO KREATION pour mur de 71 à 98 mm (n°1)",
#       "description": "Haut 2040 mm x Larg 830 mm. Pour porte Pleinitude. Chants droits. Charnières invisibles. Gâche pour serrure 1 pt magnétique. Coloris : M05 Chêne d'Orleans Taupe. Gauche poussant. Dont éco-contribution REP PMCB : 0,17€ HT. Fabrication française",
#       "quantite": 1.0,
#       "unitee_quantite": null,
#       "price_unitaire_ht": 281.08,
#       "tva": "TVA 20%",
#       "cout_additionnel": 0.17,
#       "sous_produits": null,
#       "lot": "MENUISERIE"
#     },
#     {
#       "label": "Dressing : Béquille B01 Inox PDDT",
#       "description": "Béquille B01 Inox PDDT. Dont éco-contribution REP PMCB : 0,01€ HT. Finition INOX B01",
#       "quantite": 1.0,
#       "unitee_quantite": null,
#       "price_unitaire_ht": 47.88,
#       "tva": "TVA 20%",
#       "cout_additionnel": 0.01,
#       "sous_produits": null,
#       "lot": "MENUISERIE"
#     },
#     {
#       "label": "Chambre 1 : Porte Plane Kreation - Ame pleine",
#       "description": "Haut 2040 mm x Larg 830 mm. Porte ferrée pour Clypso Kreation. 1 vantail. Chants droits. Coloris : M05 Chêne d'Orleans Taupe. Charnières invisibles. Joint en traverse basse : 1 lèvre non coupe feu. Serrure PD 1/2 tour magnétique axe à 50 mm. Droite poussant. Avec emballage. Dont éco-contribution REP PMCB : 1,18€ HT. Fabrication française",
#       "quantite": 1.0,
#       "unitee_quantite": null,
#       "price_unitaire_ht": 210.33,
#       "tva": "TVA 20%",
#       "cout_additionnel": 1.18,
#       "sous_produits": null,
#       "lot": "MENUISERIE"
#     },
#     {
#       "label": "Chambre 1 : CLYPSO KREATION pour mur de 71 à 98 mm (n°1)",
#       "description": "Haut 2040 mm x Larg 830 mm. Pour porte Pleinitude. Chants droits. Charnières invisibles. Gâche pour serrure 1 pt magnétique. Coloris : M05 Chêne d'Orleans Taupe. Droite poussant. Dont éco-contribution REP PMCB : 0,17€ HT. Fabrication française",
#       "quantite": 1.0,
#       "unitee_quantite": null,
#       "price_unitaire_ht": 281.08,
#       "tva": "TVA 20%",
#       "cout_additionnel": 0.17,
#       "sous_produits": null,
#       "lot": "MENUISERIE"
#     },
#     {
#       "label": "Chambre 1 : Béquille B01 Inox PDDT",
#       "description": "Béquille B01 Inox PDDT. Dont éco-contribution REP PMCB : 0,01€ HT. Finition INOX B01",
#       "quantite": 1.0,
#       "unitee_quantite": null,
#       "price_unitaire_ht": 47.88,
#       "tva": "TVA 20%",
#       "cout_additionnel": 0.01,
#       "sous_produits": null,
#       "lot": "MENUISERIE"
#     },
#     {
#       "label": "Chambre 2 : Porte Plane Kreation - Ame pleine",
#       "description": "Haut 2040 mm x Larg 830 mm. Porte ferrée pour Clypso Kreation. 1 vantail. Chants droits. Coloris : M05 Chêne d'Orleans Taupe. Charnières invisibles. Joint en traverse basse : 1 lèvre non coupe feu. Serrure PD 1/2 tour magnétique axe à 50 mm. Gauche poussant. Avec emballage. Dont éco-contribution REP PMCB : 1,18€ HT. Fabrication française",
#       "quantite": 1.0,
#       "unitee_quantite": null,
#       "price_unitaire_ht": 210.33,
#       "tva": "TVA 20%",
#       "cout_additionnel": 1.18,
#       "sous_produits": null,
#       "lot": "MENUISERIE"
#     },
#     {
#       "label": "Chambre 2 : CLYPSO KREATION pour mur de 71 à 98 mm (n°1)",
#       "description": "Haut 2040 mm x Larg 830 mm. Pour porte Pleinitude. Chants droits. Charnières invisibles. Gâche pour serrure 1 pt magnétique. Coloris : M05 Chêne d'Orleans Taupe. Gauche poussant. Dont éco-contribution REP PMCB : 0,17€ HT. Fabrication française",
#       "quantite": 1.0,
#       "unitee_quantite": null,
#       "price_unitaire_ht": 281.08,
#       "tva": "TVA 20%",
#       "cout_additionnel": 0.17,
#       "sous_produits": null,
#       "lot": "MENUISERIE"
#     },
#     {
#       "label": "Chambre 2 : Béquille B01 Inox PDDT",
#       "description": "Béquille B01 Inox PDDT. Dont éco-contribution REP PMCB : 0,01€ HT. Finition INOX B01",
#       "quantite": 1.0,
#       "unitee_quantite": null,
#       "price_unitaire_ht": 47.88,
#       "tva": "TVA 20%",
#       "cout_additionnel": 0.01,
#       "sous_produits": null,
#       "lot": "MENUISERIE"
#     },
#     {
#       "label": "Salle d'eau 1 : Porte Plane Kreation - Ame pleine",
#       "description": "Haut 2040 mm x Larg 830 mm. Porte ferrée pour Clypso Kreation. 1 vantail. Chants droits. Coloris : M05 Chêne d'Orleans Taupe. Charnières invisibles. Joint en traverse basse : 1 lèvre non coupe feu. Serrure Bec de cane à condamnation magnétique axe à 50 mm. Gauche poussant. Avec emballage. Dont éco-contribution REP PMCB : 1,18€ HT. Fabrication française",
#       "quantite": 1.0,
#       "unitee_quantite": null,
#       "price_unitaire_ht": 210.33,
#       "tva": "TVA 20%",
#       "cout_additionnel": 1.18,
#       "sous_produits": null,
#       "lot": "MENUISERIE"
#     },
#     {
#       "label": "Salle d'eau 1 : CLYPSO KREATION pour mur de 71 à 98 mm (n°1)",
#       "description": "Haut 2040 mm x Larg 830 mm. Pour porte Pleinitude. Chants droits. Charnières invisibles. Gâche pour serrure 1 pt magnétique. Coloris : M05 Chêne d'Orleans Taupe. Gauche poussant. Dont éco-contribution REP PMCB : 0,17€ HT. Fabrication française",
#       "quantite": 1.0,
#       "unitee_quantite": null,
#       "price_unitaire_ht": 281.08,
#       "tva": "TVA 20%",
#       "cout_additionnel": 0.17,
#       "sous_produits": null,
#       "lot": "MENUISERIE"
#     },
#     {
#       "label": "Salle d'eau 1 : Béquille B01 Inox BCC",
#       "description": "Béquille B01 Inox BCC. Dont éco-contribution REP PMCB : 0,01€ HT. Finition INOX B01",
#       "quantite": 1.0,
#       "unitee_quantite": null,
#       "price_unitaire_ht": 68.58,
#       "tva": "TVA 20%",
#       "cout_additionnel": 0.01,
#       "sous_produits": null,
#       "lot": "MENUISERIE"
#     },
#     {
#       "label": "Bureau : Porte Plane Kreation - Ame pleine",
#       "description": "Haut 2040 mm x Larg 830 mm. Porte coulissante. 1 vantail. Chants droits. Coloris : M05 Chêne d'Orleans Taupe. Habillage pour cloison 98mm : coloris Chêne d'Orleans Taupe M05. Entaillage serrure pour porte coulissante, mortaise + cuvette + tire doigt. Sens d'ouverture à définir. Rainure en traverse basse. Avec emballage. Dont éco-contribution REP PMCB : 1,35€ HT. Fabrication française",
#       "quantite": 1.0,
#       "unitee_quantite": null,
#       "price_unitaire_ht": 469.22,
#       "tva": "TVA 20%",
#       "cout_additionnel": 1.35,
#       "sous_produits": null,
#       "lot": "MENUISERIE"
#     },
#     {
#       "label": "Bureau : CHASSIS ECLISSE 95",
#       "description": "Châssis eclisse 95 UNIQUE pour Plaques de plâtre, Epaisseur cloison finie de 95 mm, version prémontée compris châssis métallique",
#       "quantite": 1.0,
#       "unitee_quantite": null,
#       "price_unitaire_ht": 399.5,
#       "tva": "TVA 20%",
#       "cout_additionnel": null,
#       "sous_produits": null,
#       "lot": "MENUISERIE"
#     },
#     {
#       "label": "Bureau : GARNITURE SERRURE L",
#       "description": "GARNITURE CHROME SATINE AVEC SERRURE BCC",
#       "quantite": 1.0,
#       "unitee_quantite": null,
#       "price_unitaire_ht": 50.34,
#       "tva": "TVA 20%",
#       "cout_additionnel": null,
#       "sous_produits": null,
#       "lot": "MENUISERIE"
#     },
#     {
#       "label": "Toilettes 3 : Porte Plane Kreation - Ame pleine",
#       "description": "Haut 2040 mm x Larg 830 mm. Porte ferrée pour Clypso Kreation. 1 vantail. Chants droits. Coloris : M05 Chêne d'Orleans Taupe. Charnières invisibles. Joint en traverse basse : 1 lèvre non coupe feu. Serrure Bec de cane à condamnation magnétique axe à 50 mm. Droite poussant. Avec emballage. Dont éco-contribution REP PMCB : 1,18€ HT. Fabrication française",
#       "quantite": 1.0,
#       "unitee_quantite": null,
#       "price_unitaire_ht": 210.33,
#       "tva": "TVA 20%",
#       "cout_additionnel": 1.18,
#       "sous_produits": null,
#       "lot": "MENUISERIE"
#     },
#     {
#       "label": "Toilettes 3 : CLYPSO KREATION pour mur de 71 à 98 mm (n°1)",
#       "description": "Haut 2040 mm x Larg 830 mm. Pour porte Pleinitude. Chants droits. Charnières invisibles. Gâche pour serrure 1 pt magnétique. Coloris : M05 Chêne d'Orleans Taupe. Droite poussant. Dont éco-contribution REP PMCB : 0,17€ HT. Fabrication française",
#       "quantite": 1.0,
#       "unitee_quantite": null,
#       "price_unitaire_ht": 281.08,
#       "tva": "TVA 20%",
#       "cout_additionnel": 0.17,
#       "sous_produits": null,
#       "lot": "MENUISERIE"
#     },
#     {
#       "label": "Toilettes 3 : Béquille B01 Inox BCC",
#       "description": "Béquille B01 Inox BCC. Dont éco-contribution REP PMCB : 0,01€ HT. Finition INOX B01",
#       "quantite": 1.0,
#       "unitee_quantite": null,
#       "price_unitaire_ht": 68.58,
#       "tva": "TVA 20%",
#       "cout_additionnel": 0.01,
#       "sous_produits": null,
#       "lot": "MENUISERIE"
#     },
#     {
#       "label": "Salle d'eau 2 : Porte Plane Kreation - Ame pleine",
#       "description": "Haut 2040 mm x Larg 830 mm. Porte ferrée pour Clypso Kreation. 1 vantail. Chants droits. Coloris : M05 Chêne d'Orleans Taupe. Charnières invisibles. Joint en traverse basse : 1 lèvre non coupe feu. Serrure Bec de cane à condamnation magnétique axe à 50 mm. Droite poussant. Avec emballage. Dont éco-contribution REP PMCB : 1,18€ HT. Fabrication française",
#       "quantite": 1.0,
#       "unitee_quantite": null,
#       "price_unitaire_ht": 210.33,
#       "tva": "TVA 20%",
#       "cout_additionnel": 1.18,
#       "sous_produits": null,
#       "lot": "MENUISERIE"
#     },
#     {
#       "label": "Salle d'eau 2 : CLYPSO KREATION pour mur de 71 à 98 mm (n°1)",
#       "description": "Haut 2040 mm x Larg 830 mm. Pour porte Pleinitude. Chants droits. Charnières invisibles. Gâche pour serrure 1 pt magnétique. Coloris : M05 Chêne d'Orleans Taupe. Droite poussant. Dont éco-contribution REP PMCB : 0,17€ HT. Fabrication française",
#       "quantite": 1.0,
#       "unitee_quantite": null,
#       "price_unitaire_ht": 281.08,
#       "tva": "TVA 20%",
#       "cout_additionnel": 0.17,
#       "sous_produits": null,
#       "lot": "MENUISERIE"
#     },
#     {
#       "label": "Salle d'eau 2 : Béquille B01 Inox BCC",
#       "description": "Béquille B01 Inox BCC. Dont éco-contribution REP PMCB : 0,01€ HT. Finition INOX B01",
#       "quantite": 1.0,
#       "unitee_quantite": null,
#       "price_unitaire_ht": 68.58,
#       "tva": "TVA 20%",
#       "cout_additionnel": 0.01,
#       "sous_produits": null,
#       "lot": "MENUISERIE"
#     },
#     {
#       "label": "Chambre 4 : Porte Plane Kreation - Ame pleine",
#       "description": "Haut 2040 mm x Larg 830 mm. Porte ferrée pour Clypso Kreation. 1 vantail. Chants droits. Coloris : M05 Chêne d'Orleans Taupe. Charnières invisibles. Joint en traverse basse : 1 lèvre non coupe feu. Serrure PD 1/2 tour magnétique axe à 50 mm. Gauche poussant. Avec emballage. Dont éco-contribution REP PMCB : 1,18€ HT. Fabrication française",
#       "quantite": 1.0,
#       "unitee_quantite": null,
#       "price_unitaire_ht": 210.33,
#       "tva": "TVA 20%",
#       "cout_additionnel": 1.18,
#       "sous_produits": null,
#       "lot": "MENUISERIE"
#     },
#     {
#       "label": "Chambre 4 : CLYPSO KREATION pour mur de 71 à 98 mm (n°1)",
#       "description": "Haut 2040 mm x Larg 830 mm. Pour porte Pleinitude. Chants droits. Charnières invisibles. Gâche pour serrure 1 pt magnétique. Coloris : M05 Chêne d'Orleans Taupe. Gauche poussant. Dont éco-contribution REP PMCB : 0,17€ HT. Fabrication française",
#       "quantite": 1.0,
#       "unitee_quantite": null,
#       "price_unitaire_ht": 281.08,
#       "tva": "TVA 20%",
#       "cout_additionnel": 0.17,
#       "sous_produits": null,
#       "lot": "MENUISERIE"
#     },
#     {
#       "label": "Chambre 4 : Béquille B01 Inox PDDT",
#       "description": "Béquille B01 Inox PDDT. Dont éco-contribution REP PMCB : 0,01€ HT. Finition INOX B01",
#       "quantite": 1.0,
#       "unitee_quantite": null,
#       "price_unitaire_ht": 47.88,
#       "tva": "TVA 20%",
#       "cout_additionnel": 0.01,
#       "sous_produits": null,
#       "lot": "MENUISERIE"
#     },
#     {
#       "label": "Chambre 3 : Porte Plane Kreation - Ame pleine",
#       "description": "Haut 2040 mm x Larg 830 mm. Porte ferrée pour Clypso Kreation. 1 vantail. Chants droits. Coloris : M05 Chêne d'Orleans Taupe. Charnières invisibles. Joint en traverse basse : 1 lèvre non coupe feu. Serrure PD 1/2 tour magnétique axe à 50 mm. Droite poussant. Avec emballage. Dont éco-contribution REP PMCB : 1,18€ HT. Fabrication française",
#       "quantite": 1.0,
#       "unitee_quantite": null,
#       "price_unitaire_ht": 210.33,
#       "tva": "TVA 20%",
#       "cout_additionnel": 1.18,
#       "sous_produits": null,
#       "lot": "MENUISERIE"
#     },
#     {
#       "label": "Chambre 3 : CLYPSO KREATION pour mur de 71 à 98 mm (n°1)",
#       "description": "Haut 2040 mm x Larg 830 mm. Pour porte Pleinitude. Chants droits. Charnières invisibles. Gâche pour serrure 1 pt magnétique. Coloris : M05 Chêne d'Orleans Taupe. Droite poussant. Dont éco-contribution REP PMCB : 0,17€ HT. Fabrication française",
#       "quantite": 1.0,
#       "unitee_quantite": null,
#       "price_unitaire_ht": 281.08,
#       "tva": "TVA 20%",
#       "cout_additionnel": 0.17,
#       "sous_produits": null,
#       "lot": "MENUISERIE"
#     },
#     {
#       "label": "Chambre 3 : Béquille B01 Inox PDDT",
#       "description": "Béquille B01 Inox PDDT. Dont éco-contribution REP PMCB : 0,01€ HT. Finition INOX B01",
#       "quantite": 1.0,
#       "unitee_quantite": null,
#       "price_unitaire_ht": 47.88,
#       "tva": "TVA 20%",
#       "cout_additionnel": 0.01,
#       "sous_produits": null,
#       "lot": "MENUISERIE"
#     },
#     {
#       "label": "Pose CHASSIS CIRCULAIRE: HABILLAGES - FINITIONS (mis en place par le plaquiste)",
#       "description": "Pose CHASSIS CIRCULAIRE: HABILLAGES - FINITIONS (mis en place par le plaquiste)",
#       "quantite": 1.0,
#       "unitee_quantite": null,
#       "price_unitaire_ht": 343.88,
#       "tva": "TVA 20%",
#       "cout_additionnel": null,
#       "sous_produits": null,
#       "lot": "MENUISERIE"
#     },
#     {
#       "label": "Pose des huisseries et des portes en fin de chantier avec pose des poignées et réglage",
#       "description": "Pose des huisseries et des portes en fin de chantier avec pose des poignées et réglage. Compris: contrôle avant pose",
#       "quantite": 1.0,
#       "unitee_quantite": null,
#       "price_unitaire_ht": 2200.8,
#       "tva": "TVA 20%",
#       "cout_additionnel": null,
#       "sous_produits": null,
#       "lot": "MENUISERIE"
#     }
#   ]
# }
# ✅ OBJECT prédit écrit dans /Users/remillieux/Documents/Kleek/OCR/data/proposal_object_predicted/DEVIS LOIRE MENUISERIES SERVICES (L_M_S_)_GUERIN - TESSIER - charnieres invisbles_predicted.json
# Total cost: {
#   "cost": 0.135324,
#   "cost_openai": {
#     "cost_openai_input": 0.060579999999999995,
#     "cost_openai_output": 0.074744,
#     "cost_embeddings": 0.0,
#     "cost_openai_total": 0.135324,
#     "nb_query": 2,
#     "queries": [
#       {
#         "model": "gpt-4.1",
#         "cost": 0.053212,
#         "function_name": "proposal_section_analyzer"
#       },
#       {
#         "model": "gpt-4.1-2025-04-14",
#         "cost": 0.082112,
#         "function_name": "proposal_analyzer"
#       }
#     ]
#   }
# }

# %%
ProposalObjectHandler(proposal_path=proposal_path).analyze_proposal_object()
# Out:
# 2025-06-27 19:41:53 INFO -> [app/proposal_object/proposal_object.py.proposal_object.convert_to_text.49]:                             ✅ PROPOSAL TEXT write in /Users/remillieux/Documents/Kleek/OCR/data/proposal_text/DEVIS LOIRE MENUISERIES SERVICES (L_M_S_)_GUERIN - TESSIER - charnieres invisbles.txt
# 2025-06-27 19:41:53 INFO -> [app/proposal_object/proposal_object.py.proposal_object.convert_to_pdf.65]:                              ✅ PROPOSAL PDF write in /Users/remillieux/Documents/Kleek/OCR/data/proposal_pdf_object/DEVIS LOIRE MENUISERIES SERVICES (L_M_S_)_GUERIN - TESSIER - charnieres invisbles.pdf
# 2025-06-27 19:41:53 INFO -> [app/proposal_object/proposal_object.py.proposal_object.convert_to_proposal_lines.94]:                   ✅ PROPOSAL LINES write in /Users/remillieux/Documents/Kleek/OCR/data/proposal_object_line/DEVIS LOIRE MENUISERIES SERVICES (L_M_S_)_GUERIN - TESSIER - charnieres invisbles.txt
# 2025-06-27 19:41:53 INFO -> [app/proposal_object/proposal_object.py.proposal_object.validate_proposal_object.116]:                   {
#   "computed_total_ht": 14743.18,
#   "computed_total_tva": 2948.78,
#   "computed_total_ttc": 17691.96,
#   "computed_total_cout_additionnel": 19.020000000000007,
#   "logs": [
#     "📑 Démarrage de la vérification des prix pour le devis :",
#     "📋 Feuille « Entrée : Porte circulaire » : HT = 3829.44, TVA = 765.89",
#     "📋 Feuille « Cellier : Porte Plane Kreation - Ame pleine » : HT = 210.33, TVA = 42.07",
#     "📋 Feuille « Cellier : CLYPSO KREATION pour mur de 71 à 98 mm (n°1) » : HT = 281.08, TVA = 56.22",
#     "📋 Feuille « Cellier : Béquille B01 Inox PDDT » : HT = 47.88, TVA = 9.58",
#     "📋 Feuille « Dégagement 2 : Porte Plane Kreation - Ame pleine » : HT = 210.33, TVA = 42.07",
#     "📋 Feuille « Dégagement 2 : CLYPSO KREATION pour mur de 71 à 98 mm (n°1) » : HT = 281.08, TVA = 56.22",
#     "📋 Feuille « Dégagement 2 : Béquille B01 Inox PDDT » : HT = 47.88, TVA = 9.58",
#     "📋 Feuille « Salle de musique : Porte Plane Kreation - Ame pleine » : HT = 210.33, TVA = 42.07",
#     "📋 Feuille « Salle de musique : CLYPSO KREATION pour mur de 71 à 98 mm (n°1) » : HT = 281.08, TVA = 56.22",
#     "📋 Feuille « Salle de musique : Béquille B01 Inox PDDT » : HT = 47.88, TVA = 9.58",
#     "📋 Feuille « Dégagement 1 : Porte Plane Kreation - Ame pleine » : HT = 469.22, TVA = 93.84",
#     "📋 Feuille « Dégagement 1 : CHASSIS ECLISSE 95 » : HT = 399.50, TVA = 79.90",
#     "📋 Feuille « Dégagement 1 : GARNITURE SANS SERRURE » : HT = 27.00, TVA = 5.40",
#     "📋 Feuille « Toilettes 2 : Porte Plane Kreation - Ame pleine » : HT = 210.33, TVA = 42.07",
#     "📋 Feuille « Toilettes 2 : CLYPSO KREATION pour mur de 71 à 98 mm (n°1) » : HT = 281.08, TVA = 56.22",
#     "📋 Feuille « Toilettes 2 : Béquille B01 Inox BCC » : HT = 68.58, TVA = 13.72",
#     "📋 Feuille « Dressing : Porte Plane Kreation - Ame pleine » : HT = 210.33, TVA = 42.07",
#     "📋 Feuille « Dressing : CLYPSO KREATION pour mur de 71 à 98 mm (n°1) » : HT = 281.08, TVA = 56.22",
#     "📋 Feuille « Dressing : Béquille B01 Inox PDDT » : HT = 47.88, TVA = 9.58",
#     "📋 Feuille « Chambre 1 : Porte Plane Kreation - Ame pleine » : HT = 210.33, TVA = 42.07",
#     "📋 Feuille « Chambre 1 : CLYPSO KREATION pour mur de 71 à 98 mm (n°1) » : HT = 281.08, TVA = 56.22",
#     "📋 Feuille « Chambre 1 : Béquille B01 Inox PDDT » : HT = 47.88, TVA = 9.58",
#     "📋 Feuille « Chambre 2 : Porte Plane Kreation - Ame pleine » : HT = 210.33, TVA = 42.07",
#     "📋 Feuille « Chambre 2 : CLYPSO KREATION pour mur de 71 à 98 mm (n°1) » : HT = 281.08, TVA = 56.22",
#     "📋 Feuille « Chambre 2 : Béquille B01 Inox PDDT » : HT = 47.88, TVA = 9.58",
#     "📋 Feuille « Salle d'eau 1 : Porte Plane Kreation - Ame pleine » : HT = 210.33, TVA = 42.07",
#     "📋 Feuille « Salle d'eau 1 : CLYPSO KREATION pour mur de 71 à 98 mm (n°1) » : HT = 281.08, TVA = 56.22",
#     "📋 Feuille « Salle d'eau 1 : Béquille B01 Inox BCC » : HT = 68.58, TVA = 13.72",
#     "📋 Feuille « Bureau : Porte Plane Kreation - Ame pleine » : HT = 469.22, TVA = 93.84",
#     "📋 Feuille « Bureau : CHASSIS ECLISSE 95 » : HT = 399.50, TVA = 79.90",
#     "📋 Feuille « Bureau : GARNITURE SERRURE L » : HT = 50.34, TVA = 10.07",
#     "📋 Feuille « Toilettes 3 : Porte Plane Kreation - Ame pleine » : HT = 210.33, TVA = 42.07",
#     "📋 Feuille « Toilettes 3 : CLYPSO KREATION pour mur de 71 à 98 mm (n°1) » : HT = 281.08, TVA = 56.22",
#     "📋 Feuille « Toilettes 3 : Béquille B01 Inox BCC » : HT = 68.58, TVA = 13.72",
#     "📋 Feuille « Salle d'eau 2 : Porte Plane Kreation - Ame pleine » : HT = 210.33, TVA = 42.07",
#     "📋 Feuille « Salle d'eau 2 : CLYPSO KREATION pour mur de 71 à 98 mm (n°1) » : HT = 281.08, TVA = 56.22",
#     "📋 Feuille « Salle d'eau 2 : Béquille B01 Inox BCC » : HT = 68.58, TVA = 13.72",
#     "📋 Feuille « Chambre 4 : Porte Plane Kreation - Ame pleine » : HT = 210.33, TVA = 42.07",
#     "📋 Feuille « Chambre 4 : CLYPSO KREATION pour mur de 71 à 98 mm (n°1) » : HT = 281.08, TVA = 56.22",
#     "📋 Feuille « Chambre 4 : Béquille B01 Inox PDDT » : HT = 47.88, TVA = 9.58",
#     "📋 Feuille « Chambre 3 : Porte Plane Kreation - Ame pleine » : HT = 210.33, TVA = 42.07",
#     "📋 Feuille « Chambre 3 : CLYPSO KREATION pour mur de 71 à 98 mm (n°1) » : HT = 281.08, TVA = 56.22",
#     "📋 Feuille « Chambre 3 : Béquille B01 Inox PDDT » : HT = 47.88, TVA = 9.58",
#     "📋 Feuille « Pose CHASSIS CIRCULAIRE: HABILLAGES - FINITIONS (mis en place par le plaquiste) » : HT = 343.88, TVA = 68.78",
#     "📋 Feuille « Pose des huisseries et des portes en fin de chantier avec pose des poignées et réglage » : HT = 2200.80, TVA = 440.16",
#     "🔍 Coût additionnel total déclaré = None",
#     "🧮 Coût additionnel total calculé = 19.020000000000007",
#     "❌ Écart coût additionnel total : déclaré None ↔ calculé 19.020000000000007",
#     "🏁 HT total calculé du devis = 14743.18",
#     "🏁 TVA totale calculée du devis = 2948.78",
#     "🏁 TTC total calculé du devis = 17691.96",
#     "🔍 HT déclaré = 14743.18",
#     "✅ HT global cohérent",
#     "🔍 TVA déclaré = 2948.64",
#     "❌ Écart TVA global : déclaré 2948.64 ↔ calculé 2948.78",
#     "🔍 TTC déclaré = 17691.82",
#     "❌ Écart TTC global : déclaré 17691.82 ↔ calculé 17691.96"
#   ],
#   "errors": [
#     "❌ Écart coût additionnel total : déclaré None ↔ calculé 19.020000000000007",
#     "❌ Écart TVA global : déclaré 2948.64 ↔ calculé 2948.78",
#     "❌ Écart TTC global : déclaré 17691.82 ↔ calculé 17691.96"
#   ]
# }
# 2025-06-27 19:41:53 INFO -> [app/proposal_object/proposal_object.py.proposal_object.validate_proposal_object.118]:                   ✅ PROPOSAL VALIDATION write in /Users/remillieux/Documents/Kleek/OCR/data/proposal_validation/DEVIS LOIRE MENUISERIES SERVICES (L_M_S_)_GUERIN - TESSIER - charnieres invisbles.txt
# arraybcimunnm = [
#     "|    PACK    |   TVA   |                                         LABEL                                          |                                                                                                                                                                                                                            DESCRIPTION                                                                                                                                                                                                                            | QTY | UNIT | UNIT_PRICE_HT | TOTAL_HT |",
#     "|------------|---------|----------------------------------------------------------------------------------------|-------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------|-----|------|---------------|----------|",
#     "| MENUISERIE | TVA 20% |                               Entrée : Porte circulaire                                | Châssis unique version CIRCULAR plaque de plâtre rayon 1200 ouverture à droite pour porte de LP=830 HP=2040 mm - Porte + Habillage + Couvre-joints unique version CIRCULAR plaqué Tanganika rayon 1200 ouverture à droite pour porte de LP= 830 HP=2040 mm - Kit AGB RONDO (serrure condamnation/décondamnation) finition Chromé Satiné pour porte coulissante bois (ép. 40 mm). SOUS RESERVE D'UN DESCRIPTIF TECHNIQUE PLUS PRECIS POUR ADAPTER AU BESOIN CLIENT |  1  |      |    3829.44    | 3829.44  |",
#     "| MENUISERIE | TVA 20% |                      Cellier : Porte Plane Kreation - Ame pleine                       |                                                        Haut 2040 mm x Larg 830 mm. Porte ferrée pour Clypso Kreation. 1 vantail. Chants droits. Coloris : M05 Chêne d'Orleans Taupe. Charnières invisibles. Joint en traverse basse : 1 lèvre non coupe feu. Serrure PD 1/2 tour magnétique axe à 50 mm. Gauche poussant. Avec emballage. Dont éco-contribution REP PMCB : 1,18€ HT. Fabrication française                                                        |  1  |      |     210.33    |  210.33  |",
#     "| MENUISERIE | TVA 20% |                 Cellier : CLYPSO KREATION pour mur de 71 à 98 mm (n°1)                 |                                                                                                        Haut 2040 mm x Larg 830 mm. Pour porte Pleinitude. Chants droits. Charnières invisibles. Gâche pour serrure 1 pt magnétique. Coloris : M05 Chêne d'Orleans Taupe. Gauche poussant. Dont éco-contribution REP PMCB : 0,17€ HT. Fabrication française                                                                                                        |  1  |      |     281.08    |  281.08  |",
#     "| MENUISERIE | TVA 20% |                            Cellier : Béquille B01 Inox PDDT                            |                                                                                                                                                                                        Béquille B01 Inox PDDT. Dont éco-contribution REP PMCB : 0,01€ HT. Finition INOX B01                                                                                                                                                                                       |  1  |      |     47.88     |  47.88   |",
#     "| MENUISERIE | TVA 20% |                    Dégagement 2 : Porte Plane Kreation - Ame pleine                    |                                                        Haut 2040 mm x Larg 830 mm. Porte ferrée pour Clypso Kreation. 1 vantail. Chants droits. Coloris : M05 Chêne d'Orleans Taupe. Charnières invisibles. Joint en traverse basse : 1 lèvre non coupe feu. Serrure PD 1/2 tour magnétique axe à 50 mm. Droite poussant. Avec emballage. Dont éco-contribution REP PMCB : 1,18€ HT. Fabrication française                                                        |  1  |      |     210.33    |  210.33  |",
#     "| MENUISERIE | TVA 20% |              Dégagement 2 : CLYPSO KREATION pour mur de 71 à 98 mm (n°1)               |                                                                                                        Haut 2040 mm x Larg 830 mm. Pour porte Pleinitude. Chants droits. Charnières invisibles. Gâche pour serrure 1 pt magnétique. Coloris : M05 Chêne d'Orleans Taupe. Droite poussant. Dont éco-contribution REP PMCB : 0,17€ HT. Fabrication française                                                                                                        |  1  |      |     281.08    |  281.08  |",
#     "| MENUISERIE | TVA 20% |                         Dégagement 2 : Béquille B01 Inox PDDT                          |                                                                                                                                                                                        Béquille B01 Inox PDDT. Dont éco-contribution REP PMCB : 0,01€ HT. Finition INOX B01                                                                                                                                                                                       |  1  |      |     47.88     |  47.88   |",
#     "| MENUISERIE | TVA 20% |                  Salle de musique : Porte Plane Kreation - Ame pleine                  |                                                        Haut 2040 mm x Larg 830 mm. Porte ferrée pour Clypso Kreation. 1 vantail. Chants droits. Coloris : M05 Chêne d'Orleans Taupe. Charnières invisibles. Joint en traverse basse : 1 lèvre non coupe feu. Serrure PD 1/2 tour magnétique axe à 50 mm. Gauche poussant. Avec emballage. Dont éco-contribution REP PMCB : 1,18€ HT. Fabrication française                                                        |  1  |      |     210.33    |  210.33  |",
#     "| MENUISERIE | TVA 20% |            Salle de musique : CLYPSO KREATION pour mur de 71 à 98 mm (n°1)             |                                                                                                        Haut 2040 mm x Larg 830 mm. Pour porte Pleinitude. Chants droits. Charnières invisibles. Gâche pour serrure 1 pt magnétique. Coloris : M05 Chêne d'Orleans Taupe. Gauche poussant. Dont éco-contribution REP PMCB : 0,17€ HT. Fabrication française                                                                                                        |  1  |      |     281.08    |  281.08  |",
#     "| MENUISERIE | TVA 20% |                       Salle de musique : Béquille B01 Inox PDDT                        |                                                                                                                                                                                        Béquille B01 Inox PDDT. Dont éco-contribution REP PMCB : 0,01€ HT. Finition INOX B01                                                                                                                                                                                       |  1  |      |     47.88     |  47.88   |",
#     "| MENUISERIE | TVA 20% |                    Dégagement 1 : Porte Plane Kreation - Ame pleine                    |                                      Haut 2040 mm x Larg 830 mm. Porte coulissante. 1 vantail. Chants droits. Coloris : M05 Chêne d'Orleans Taupe. Habillage pour cloison 98mm : coloris Chêne d'Orleans Taupe M05. Entaillage serrure pour porte coulissante, cuvette + tire doigt. Sens d'ouverture à définir. Rainure en traverse basse. Avec emballage. Dont éco-contribution REP PMCB : 1,35€ HT. Fabrication française                                      |  1  |      |     469.22    |  469.22  |",
#     "| MENUISERIE | TVA 20% |                           Dégagement 1 : CHASSIS ECLISSE 95                            |                                                                                                                                                                  Châssis eclisse 95 UNIQUE pour Plaques de plâtre, Epaisseur cloison finie de 95 mm, version prémontée compris châssis métallique                                                                                                                                                                 |  1  |      |     399.50    |  399.50  |",
#     "| MENUISERIE | TVA 20% |                         Dégagement 1 : GARNITURE SANS SERRURE                          |                                                                                                                                                                                                      GARNITURE CHROME SATINE SANS SERRURE SANS PLAQUE TETIERE                                                                                                                                                                                                     |  1  |      |     27.00     |  27.00   |",
#     "| MENUISERIE | TVA 20% |                    Toilettes 2 : Porte Plane Kreation - Ame pleine                     |                                                 Haut 2040 mm x Larg 830 mm. Porte ferrée pour Clypso Kreation. 1 vantail. Chants droits. Coloris : M05 Chêne d'Orleans Taupe. Charnières invisibles. Joint en traverse basse : 1 lèvre non coupe feu. Serrure Bec de cane à condamnation magnétique axe à 50 mm. Droite poussant. Avec emballage. Dont éco-contribution REP PMCB : 1,18€ HT. Fabrication française                                                |  1  |      |     210.33    |  210.33  |",
#     "| MENUISERIE | TVA 20% |               Toilettes 2 : CLYPSO KREATION pour mur de 71 à 98 mm (n°1)               |                                                                                                        Haut 2040 mm x Larg 830 mm. Pour porte Pleinitude. Chants droits. Charnières invisibles. Gâche pour serrure 1 pt magnétique. Coloris : M05 Chêne d'Orleans Taupe. Droite poussant. Dont éco-contribution REP PMCB : 0,17€ HT. Fabrication française                                                                                                        |  1  |      |     281.08    |  281.08  |",
#     "| MENUISERIE | TVA 20% |                          Toilettes 2 : Béquille B01 Inox BCC                           |                                                                                                                                                                                        Béquille B01 Inox BCC. Dont éco-contribution REP PMCB : 0,01€ HT. Finition INOX B01                                                                                                                                                                                        |  1  |      |     68.58     |  68.58   |",
#     "| MENUISERIE | TVA 20% |                      Dressing : Porte Plane Kreation - Ame pleine                      |                                                        Haut 2040 mm x Larg 830 mm. Porte ferrée pour Clypso Kreation. 1 vantail. Chants droits. Coloris : M05 Chêne d'Orleans Taupe. Charnières invisibles. Joint en traverse basse : 1 lèvre non coupe feu. Serrure PD 1/2 tour magnétique axe à 50 mm. Gauche poussant. Avec emballage. Dont éco-contribution REP PMCB : 1,18€ HT. Fabrication française                                                        |  1  |      |     210.33    |  210.33  |",
#     "| MENUISERIE | TVA 20% |                Dressing : CLYPSO KREATION pour mur de 71 à 98 mm (n°1)                 |                                                                                                        Haut 2040 mm x Larg 830 mm. Pour porte Pleinitude. Chants droits. Charnières invisibles. Gâche pour serrure 1 pt magnétique. Coloris : M05 Chêne d'Orleans Taupe. Gauche poussant. Dont éco-contribution REP PMCB : 0,17€ HT. Fabrication française                                                                                                        |  1  |      |     281.08    |  281.08  |",
#     "| MENUISERIE | TVA 20% |                           Dressing : Béquille B01 Inox PDDT                            |                                                                                                                                                                                        Béquille B01 Inox PDDT. Dont éco-contribution REP PMCB : 0,01€ HT. Finition INOX B01                                                                                                                                                                                       |  1  |      |     47.88     |  47.88   |",
#     "| MENUISERIE | TVA 20% |                     Chambre 1 : Porte Plane Kreation - Ame pleine                      |                                                        Haut 2040 mm x Larg 830 mm. Porte ferrée pour Clypso Kreation. 1 vantail. Chants droits. Coloris : M05 Chêne d'Orleans Taupe. Charnières invisibles. Joint en traverse basse : 1 lèvre non coupe feu. Serrure PD 1/2 tour magnétique axe à 50 mm. Droite poussant. Avec emballage. Dont éco-contribution REP PMCB : 1,18€ HT. Fabrication française                                                        |  1  |      |     210.33    |  210.33  |",
#     "| MENUISERIE | TVA 20% |                Chambre 1 : CLYPSO KREATION pour mur de 71 à 98 mm (n°1)                |                                                                                                        Haut 2040 mm x Larg 830 mm. Pour porte Pleinitude. Chants droits. Charnières invisibles. Gâche pour serrure 1 pt magnétique. Coloris : M05 Chêne d'Orleans Taupe. Droite poussant. Dont éco-contribution REP PMCB : 0,17€ HT. Fabrication française                                                                                                        |  1  |      |     281.08    |  281.08  |",
#     "| MENUISERIE | TVA 20% |                           Chambre 1 : Béquille B01 Inox PDDT                           |                                                                                                                                                                                        Béquille B01 Inox PDDT. Dont éco-contribution REP PMCB : 0,01€ HT. Finition INOX B01                                                                                                                                                                                       |  1  |      |     47.88     |  47.88   |",
#     "| MENUISERIE | TVA 20% |                     Chambre 2 : Porte Plane Kreation - Ame pleine                      |                                                        Haut 2040 mm x Larg 830 mm. Porte ferrée pour Clypso Kreation. 1 vantail. Chants droits. Coloris : M05 Chêne d'Orleans Taupe. Charnières invisibles. Joint en traverse basse : 1 lèvre non coupe feu. Serrure PD 1/2 tour magnétique axe à 50 mm. Gauche poussant. Avec emballage. Dont éco-contribution REP PMCB : 1,18€ HT. Fabrication française                                                        |  1  |      |     210.33    |  210.33  |",
#     "| MENUISERIE | TVA 20% |                Chambre 2 : CLYPSO KREATION pour mur de 71 à 98 mm (n°1)                |                                                                                                        Haut 2040 mm x Larg 830 mm. Pour porte Pleinitude. Chants droits. Charnières invisibles. Gâche pour serrure 1 pt magnétique. Coloris : M05 Chêne d'Orleans Taupe. Gauche poussant. Dont éco-contribution REP PMCB : 0,17€ HT. Fabrication française                                                                                                        |  1  |      |     281.08    |  281.08  |",
#     "| MENUISERIE | TVA 20% |                           Chambre 2 : Béquille B01 Inox PDDT                           |                                                                                                                                                                                        Béquille B01 Inox PDDT. Dont éco-contribution REP PMCB : 0,01€ HT. Finition INOX B01                                                                                                                                                                                       |  1  |      |     47.88     |  47.88   |",
#     "| MENUISERIE | TVA 20% |                   Salle d'eau 1 : Porte Plane Kreation - Ame pleine                    |                                                 Haut 2040 mm x Larg 830 mm. Porte ferrée pour Clypso Kreation. 1 vantail. Chants droits. Coloris : M05 Chêne d'Orleans Taupe. Charnières invisibles. Joint en traverse basse : 1 lèvre non coupe feu. Serrure Bec de cane à condamnation magnétique axe à 50 mm. Gauche poussant. Avec emballage. Dont éco-contribution REP PMCB : 1,18€ HT. Fabrication française                                                |  1  |      |     210.33    |  210.33  |",
#     "| MENUISERIE | TVA 20% |              Salle d'eau 1 : CLYPSO KREATION pour mur de 71 à 98 mm (n°1)              |                                                                                                        Haut 2040 mm x Larg 830 mm. Pour porte Pleinitude. Chants droits. Charnières invisibles. Gâche pour serrure 1 pt magnétique. Coloris : M05 Chêne d'Orleans Taupe. Gauche poussant. Dont éco-contribution REP PMCB : 0,17€ HT. Fabrication française                                                                                                        |  1  |      |     281.08    |  281.08  |",
#     "| MENUISERIE | TVA 20% |                         Salle d'eau 1 : Béquille B01 Inox BCC                          |                                                                                                                                                                                        Béquille B01 Inox BCC. Dont éco-contribution REP PMCB : 0,01€ HT. Finition INOX B01                                                                                                                                                                                        |  1  |      |     68.58     |  68.58   |",
#     "| MENUISERIE | TVA 20% |                       Bureau : Porte Plane Kreation - Ame pleine                       |                                 Haut 2040 mm x Larg 830 mm. Porte coulissante. 1 vantail. Chants droits. Coloris : M05 Chêne d'Orleans Taupe. Habillage pour cloison 98mm : coloris Chêne d'Orleans Taupe M05. Entaillage serrure pour porte coulissante, mortaise + cuvette + tire doigt. Sens d'ouverture à définir. Rainure en traverse basse. Avec emballage. Dont éco-contribution REP PMCB : 1,35€ HT. Fabrication française                                |  1  |      |     469.22    |  469.22  |",
#     "| MENUISERIE | TVA 20% |                              Bureau : CHASSIS ECLISSE 95                               |                                                                                                                                                                  Châssis eclisse 95 UNIQUE pour Plaques de plâtre, Epaisseur cloison finie de 95 mm, version prémontée compris châssis métallique                                                                                                                                                                 |  1  |      |     399.50    |  399.50  |",
#     "| MENUISERIE | TVA 20% |                              Bureau : GARNITURE SERRURE L                              |                                                                                                                                                                                                              GARNITURE CHROME SATINE AVEC SERRURE BCC                                                                                                                                                                                                             |  1  |      |     50.34     |  50.34   |",
#     "| MENUISERIE | TVA 20% |                    Toilettes 3 : Porte Plane Kreation - Ame pleine                     |                                                 Haut 2040 mm x Larg 830 mm. Porte ferrée pour Clypso Kreation. 1 vantail. Chants droits. Coloris : M05 Chêne d'Orleans Taupe. Charnières invisibles. Joint en traverse basse : 1 lèvre non coupe feu. Serrure Bec de cane à condamnation magnétique axe à 50 mm. Droite poussant. Avec emballage. Dont éco-contribution REP PMCB : 1,18€ HT. Fabrication française                                                |  1  |      |     210.33    |  210.33  |",
#     "| MENUISERIE | TVA 20% |               Toilettes 3 : CLYPSO KREATION pour mur de 71 à 98 mm (n°1)               |                                                                                                        Haut 2040 mm x Larg 830 mm. Pour porte Pleinitude. Chants droits. Charnières invisibles. Gâche pour serrure 1 pt magnétique. Coloris : M05 Chêne d'Orleans Taupe. Droite poussant. Dont éco-contribution REP PMCB : 0,17€ HT. Fabrication française                                                                                                        |  1  |      |     281.08    |  281.08  |",
#     "| MENUISERIE | TVA 20% |                          Toilettes 3 : Béquille B01 Inox BCC                           |                                                                                                                                                                                        Béquille B01 Inox BCC. Dont éco-contribution REP PMCB : 0,01€ HT. Finition INOX B01                                                                                                                                                                                        |  1  |      |     68.58     |  68.58   |",
#     "| MENUISERIE | TVA 20% |                   Salle d'eau 2 : Porte Plane Kreation - Ame pleine                    |                                                 Haut 2040 mm x Larg 830 mm. Porte ferrée pour Clypso Kreation. 1 vantail. Chants droits. Coloris : M05 Chêne d'Orleans Taupe. Charnières invisibles. Joint en traverse basse : 1 lèvre non coupe feu. Serrure Bec de cane à condamnation magnétique axe à 50 mm. Droite poussant. Avec emballage. Dont éco-contribution REP PMCB : 1,18€ HT. Fabrication française                                                |  1  |      |     210.33    |  210.33  |",
#     "| MENUISERIE | TVA 20% |              Salle d'eau 2 : CLYPSO KREATION pour mur de 71 à 98 mm (n°1)              |                                                                                                        Haut 2040 mm x Larg 830 mm. Pour porte Pleinitude. Chants droits. Charnières invisibles. Gâche pour serrure 1 pt magnétique. Coloris : M05 Chêne d'Orleans Taupe. Droite poussant. Dont éco-contribution REP PMCB : 0,17€ HT. Fabrication française                                                                                                        |  1  |      |     281.08    |  281.08  |",
#     "| MENUISERIE | TVA 20% |                         Salle d'eau 2 : Béquille B01 Inox BCC                          |                                                                                                                                                                                        Béquille B01 Inox BCC. Dont éco-contribution REP PMCB : 0,01€ HT. Finition INOX B01                                                                                                                                                                                        |  1  |      |     68.58     |  68.58   |",
#     "| MENUISERIE | TVA 20% |                     Chambre 4 : Porte Plane Kreation - Ame pleine                      |                                                        Haut 2040 mm x Larg 830 mm. Porte ferrée pour Clypso Kreation. 1 vantail. Chants droits. Coloris : M05 Chêne d'Orleans Taupe. Charnières invisibles. Joint en traverse basse : 1 lèvre non coupe feu. Serrure PD 1/2 tour magnétique axe à 50 mm. Gauche poussant. Avec emballage. Dont éco-contribution REP PMCB : 1,18€ HT. Fabrication française                                                        |  1  |      |     210.33    |  210.33  |",
#     "| MENUISERIE | TVA 20% |                Chambre 4 : CLYPSO KREATION pour mur de 71 à 98 mm (n°1)                |                                                                                                        Haut 2040 mm x Larg 830 mm. Pour porte Pleinitude. Chants droits. Charnières invisibles. Gâche pour serrure 1 pt magnétique. Coloris : M05 Chêne d'Orleans Taupe. Gauche poussant. Dont éco-contribution REP PMCB : 0,17€ HT. Fabrication française                                                                                                        |  1  |      |     281.08    |  281.08  |",
#     "| MENUISERIE | TVA 20% |                           Chambre 4 : Béquille B01 Inox PDDT                           |                                                                                                                                                                                        Béquille B01 Inox PDDT. Dont éco-contribution REP PMCB : 0,01€ HT. Finition INOX B01                                                                                                                                                                                       |  1  |      |     47.88     |  47.88   |",
#     "| MENUISERIE | TVA 20% |                     Chambre 3 : Porte Plane Kreation - Ame pleine                      |                                                        Haut 2040 mm x Larg 830 mm. Porte ferrée pour Clypso Kreation. 1 vantail. Chants droits. Coloris : M05 Chêne d'Orleans Taupe. Charnières invisibles. Joint en traverse basse : 1 lèvre non coupe feu. Serrure PD 1/2 tour magnétique axe à 50 mm. Droite poussant. Avec emballage. Dont éco-contribution REP PMCB : 1,18€ HT. Fabrication française                                                        |  1  |      |     210.33    |  210.33  |",
#     "| MENUISERIE | TVA 20% |                Chambre 3 : CLYPSO KREATION pour mur de 71 à 98 mm (n°1)                |                                                                                                        Haut 2040 mm x Larg 830 mm. Pour porte Pleinitude. Chants droits. Charnières invisibles. Gâche pour serrure 1 pt magnétique. Coloris : M05 Chêne d'Orleans Taupe. Droite poussant. Dont éco-contribution REP PMCB : 0,17€ HT. Fabrication française                                                                                                        |  1  |      |     281.08    |  281.08  |",
#     "| MENUISERIE | TVA 20% |                           Chambre 3 : Béquille B01 Inox PDDT                           |                                                                                                                                                                                        Béquille B01 Inox PDDT. Dont éco-contribution REP PMCB : 0,01€ HT. Finition INOX B01                                                                                                                                                                                       |  1  |      |     47.88     |  47.88   |",
#     "| MENUISERIE | TVA 20% |    Pose CHASSIS CIRCULAIRE: HABILLAGES - FINITIONS (mis en place par le plaquiste)     |                                                                                                                                                                                          Pose CHASSIS CIRCULAIRE: HABILLAGES - FINITIONS (mis en place par le plaquiste)                                                                                                                                                                                          |  1  |      |     343.88    |  343.88  |",
#     "| MENUISERIE | TVA 20% | Pose des huisseries et des portes en fin de chantier avec pose des poignées et réglage |                                                                                                                                                                        Pose des huisseries et des portes en fin de chantier avec pose des poignées et réglage. Compris: contrôle avant pose                                                                                                                                                                       |  1  |      |    2200.80    | 2200.80  |"
# ]
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[33], line 1
# ----> 1 ProposalObjectHandler(proposal_path=proposal_path).analyze_proposal_object()
#
# File ~/Documents/Kleek/OCR/app/proposal_object/proposal_object.py:164, in ProposalObjectHandler.analyze_proposal_object(self)
#     160 self.convert_to_proposal_lines()
#     162 self.validate_proposal_object()
# --> 164 self.evaluate_proposal_object()
#
# File ~/Documents/Kleek/OCR/app/proposal_object/proposal_object.py:128, in ProposalObjectHandler.evaluate_proposal_object(self)
#     123 with open(
#     124     self.proposal_path.proposal_object_predicted_path, encoding="utf-8"
#     125 ) as f:
#     126     proposal_predicted = Devis.model_validate_json(f.read())
# --> 128 with open(self.proposal_path.proposal_object_known_path, encoding="utf-8") as f:
#     129     proposal_expected = Devis.model_validate_json(f.read())
#     131 evaluation = EvaluateProposalObject(
#     132     expected=proposal_expected, predicted=proposal_predicted
#     133 ).evaluate()
#
# FileNotFoundError: [Errno 2] No such file or directory: 'data/proposal_object_know/DEVIS LOIRE MENUISERIES SERVICES (L_M_S_)_GUERIN - TESSIER - charnieres invisbles.json'
# Le noyau s’est bloqué lors de l’exécution du code dans une cellule active ou une cellule précédente.
#
# Veuillez vérifier le code dans la ou les cellules pour identifier une cause possible de l’échec.
#
# Cliquez <a href='https://aka.ms/vscodeJupyterKernelCrash'>ici</a> pour plus d’informations.
#
# Pour plus d’informations, consultez Jupyter <a href='command:jupyter.viewOutput'>log</a>.
